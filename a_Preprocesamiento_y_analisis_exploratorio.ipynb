# %% [markdown]
# <a href="https://colab.research.google.com/github/veronica1908/SALUD_E3_AIII/blob/main/a_Preprocesamiento_y_analisis_exploratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cargar paquetes y librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

# %% [markdown]
# #Cargar las bases de datos

# %%
# Cargar la base de egresos hospitalarios
df_egresos = pd.read_csv('https://raw.githubusercontent.com/veronica1908/SALUD_E3_AIII/main/RETO_df_egresos.csv')

# Cargar la base de usuarios
df_usuarios = pd.read_csv('https://raw.githubusercontent.com/veronica1908/SALUD_E3_AIII/main/RETO_df_usuarios.csv')
# Out:
# <ipython-input-15-80afb50d83cc>:5: DtypeWarning: Columns (4,6,7,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_usuarios = pd.read_csv('https://raw.githubusercontent.com/veronica1908/SALUD_E3_AIII/main/RETO_df_usuarios.csv')

# %%
# Cargar la base de datos de crónicos codificación ISO-8859-1
df_cronicos = pd.read_csv('https://raw.githubusercontent.com/veronica1908/SALUD_E3_AIII/main/RETO_df_cronicos.csv', delimiter=';', encoding='ISO-8859-1')
# Out:
# <ipython-input-16-0388d6574092>:2: DtypeWarning: Columns (34,36,39,40,50,52,55,56,58,62,64,65,66,75,107,108,111,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cronicos = pd.read_csv('https://raw.githubusercontent.com/veronica1908/SALUD_E3_AIII/main/RETO_df_cronicos.csv', delimiter=';', encoding='ISO-8859-1')

# %% [markdown]
# #Exploración inicial de los datos

# %%
print("\nPrimeras filas de la base de usuarios:")
print(df_usuarios.head())

print("\nInformación de la base de usuarios:")
print(df_usuarios.info())

# Ordenar las columnas por cantidad de datos nulos de mayor a menor
print("Variables con  datos nulos:")
sorted_null_values = df_usuarios.isnull().sum().sort_values(ascending=False)

# Mostrar los resultados
print(sorted_null_values)
# Out:
# Primeras filas de la base de usuarios:
#      MES  YEAR  NRODOC SEXO     FECHA NACIMIENTO  EDAD DEPARTAMENTO MUNICIPIO  \
# 0  ABRIL  2017  306221    F  1938-09-09 00:00:00   NaN          NaN       NaN
# 1  ABRIL  2017  306222    F  1974-07-03 00:00:00   NaN          NaN       NaN
# 2  ABRIL  2017  306223    F  1930-08-24 00:00:00   NaN          NaN       NaN
# 3  ABRIL  2017  306224    F  1979-12-01 00:00:00   NaN          NaN       NaN
# 4  ABRIL  2017  306225    M  1943-06-01 00:00:00   NaN          NaN       NaN
#
#   BARRIO FECHA INICIO AL PGP FECHA PRIMERA CLASE FUNCIONAL  \
# 0    NaN                 NaN                           NaN
# 1    NaN                 NaN                           NaN
# 2    NaN                 NaN                           NaN
# 3    NaN                 NaN                           NaN
# 4    NaN                 NaN                           NaN
#
#   PRIMERA CLASE FUNCIONAL FECHA ÚLTIMA CLASE FUNCIONAL ÚLTIMA CLASE FUNCIONAL  \
# 0                     NaN                          NaN                    NaN
# 1                     NaN                          NaN                    NaN
# 2                     NaN                          NaN                    NaN
# 3                     NaN                          NaN                    NaN
# 4                     NaN                          NaN                    NaN
#
#   CICLO_VITAL QUINQUENIO
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
#
# Información de la base de usuarios:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183911 entries, 0 to 183910
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   MES                            183911 non-null  object
#  1   YEAR                           183911 non-null  int64
#  2   NRODOC                         183911 non-null  int64
#  3   SEXO                           183901 non-null  object
#  4   FECHA NACIMIENTO               111831 non-null  object
#  5   EDAD                           149755 non-null  float64
#  6   DEPARTAMENTO                   82284 non-null   object
#  7   MUNICIPIO                      81397 non-null   object
#  8   BARRIO                         115344 non-null  object
#  9   FECHA INICIO AL PGP            125658 non-null  object
#  10  FECHA PRIMERA CLASE FUNCIONAL  87961 non-null   object
#  11  PRIMERA CLASE FUNCIONAL        89641 non-null   object
#  12  FECHA ÚLTIMA CLASE FUNCIONAL   87985 non-null   object
#  13  ÚLTIMA CLASE FUNCIONAL         128109 non-null  object
#  14  CICLO_VITAL                    149755 non-null  object
#  15  QUINQUENIO                     149755 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 22.5+ MB
# None
# Variables con  datos nulos:
# MUNICIPIO                        102514
# DEPARTAMENTO                     101627
# FECHA PRIMERA CLASE FUNCIONAL     95950
# FECHA ÚLTIMA CLASE FUNCIONAL      95926
# PRIMERA CLASE FUNCIONAL           94270
# FECHA NACIMIENTO                  72080
# BARRIO                            68567
# FECHA INICIO AL PGP               58253
# ÚLTIMA CLASE FUNCIONAL            55802
# EDAD                              34156
# CICLO_VITAL                       34156
# QUINQUENIO                        34156
# SEXO                                 10
# MES                                   0
# YEAR                                  0
# NRODOC                                0
# dtype: int64

# %%
# Mostrar las primeras filas
print("Primeras filas de la base de egresos hospitalarios:")
print(df_egresos.head())

# Información general de los dataframes
print("\nInformación de la base de egresos hospitalarios:")
print(df_egresos.info())

# Ordenar las columnas por cantidad de datos nulos de mayor a menor
print("Variables con  datos nulos:")
sorted_null_values = df_egresos.isnull().sum().sort_values(ascending=False)

# Mostrar los resultados
print(sorted_null_values)
# Out:
# Primeras filas de la base de egresos hospitalarios:
#    YEAR        MES  NRO ATENCION  NRO INGRESO  SERVICIO HABILITADO COD  \
# 0  2017       MAYO       3433964      1899917                     -1.0
# 1  2017  DICIEMBRE       3720631      2018136                     -1.0
# 2  2018    FEBRERO       3912821      2159592                    501.0
# 3  2018       MAYO       4023613      2254075                    501.0
# 4  2018      JULIO       4080166      2292863                    101.0
#
#      SERVICIO HABILITADO TIPO IDENTIFICACION  NRODOC         FECHA NACIMIENTO  \
# 0        Sin Informacion                  CC  308185  1937-07-18 00:00:00.000
# 1        Sin Informacion                  CC  308185  1937-07-18 00:00:00.000
# 2  Urgencias >= 24 horas                  CC  308185  1937-07-18 00:00:00.000
# 3  Urgencias >= 24 horas                  CC  308185  1937-07-18 00:00:00.000
# 4        General adultos                  CC  308185  1937-07-18 00:00:00.000
#
#   REGIMEN AFILIACION  ... DX PRINCIPAL EGRESO CAPITULO COD  \
# 0    Sin información  ...                          J00-J99
# 1    Sin información  ...                          J00-J99
# 2       Contributivo  ...                          J00-J99
# 3       Contributivo  ...                          I00-I99
# 4       Contributivo  ...                          I00-I99
#
#              DX PRINCIPAL EGRESO CAPITULO CAUSA BASICA MUERTE COD  \
# 0  ENFERMEDADES DEL SISTEMA RESPIRATORIO                      NaN
# 1  ENFERMEDADES DEL SISTEMA RESPIRATORIO                      NaN
# 2  ENFERMEDADES DEL SISTEMA RESPIRATORIO                      NaN
# 3  ENFERMEDADES DEL SISTEMA CIRCULATORIO                      NaN
# 4  ENFERMEDADES DEL SISTEMA CIRCULATORIO                      NaN
#
#                 CAUSA BASICA MUERTE CAUSA BASICA CATEGORIA COD  \
# 0  Sin informacion en base de datos                        NaN
# 1  Sin informacion en base de datos                        NaN
# 2  Sin informacion en base de datos                        NaN
# 3  Sin informacion en base de datos                        NaN
# 4  Sin informacion en base de datos                        NaN
#
#              CAUSA BASICA CATEGORIA CAUSA BASICA CAPITULO COD  \
# 0  Sin informacion en base de datos                       NaN
# 1  Sin informacion en base de datos                       NaN
# 2  Sin informacion en base de datos                       NaN
# 3  Sin informacion en base de datos                       NaN
# 4  Sin informacion en base de datos                       NaN
#
#               CAUSA BASICA CAPITULO          PROFESIONAL ESPECIALIDAD  \
# 0  Sin informacion en base de datos  Sin informacion en Base de datos
# 1  Sin informacion en base de datos  Sin informacion en Base de datos
# 2  Sin informacion en base de datos                  Medicina Interna
# 3  Sin informacion en base de datos                  Medicina Interna
# 4  Sin informacion en base de datos                  Medicina Interna
#
#   PROFESIONAL ESPECIALIDAD GRD
# 0             Medicina Interna
# 1             Medicina Interna
# 2                 Urgentologia
# 3                 Urgentologia
# 4             Medicina Interna
#
# [5 rows x 66 columns]
#
# Información de la base de egresos hospitalarios:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6376 entries, 0 to 6375
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   YEAR                               6376 non-null   int64
#  1   MES                                6376 non-null   object
#  2   NRO ATENCION                       6376 non-null   int64
#  3   NRO INGRESO                        6376 non-null   int64
#  4   SERVICIO HABILITADO COD            6376 non-null   float64
#  5   SERVICIO HABILITADO                6376 non-null   object
#  6   TIPO IDENTIFICACION                6376 non-null   object
#  7   NRODOC                             6376 non-null   int64
#  8   FECHA NACIMIENTO                   6376 non-null   object
#  9   REGIMEN AFILIACION                 6376 non-null   object
#  10  EPS VALIDADA                       4103 non-null   object
#  11  MODALIDAD CONTRATO                 6376 non-null   object
#  12  FUENTE FINANCIACION1               6376 non-null   object
#  13  FUENTE FINANCIACION2               6376 non-null   object
#  14  SERVICIO ADMITE                    6376 non-null   object
#  15  BLOQUE ANTERIOR                    6376 non-null   object
#  16  PISO ANTERIOR                      6376 non-null   object
#  17  SERVICIO ANTERIOR                  6376 non-null   object
#  18  NRO CAMA ANTERIOR                  6376 non-null   object
#  19  VIA INGRESO                        6376 non-null   object
#  20  BLOQUE                             6376 non-null   object
#  21  UNIDAD ESTRATEGICA                 6376 non-null   object
#  22  PISO                               6376 non-null   object
#  23  NRO CAMA                           6376 non-null   object
#  24  SERVICIO EGRESO                    6376 non-null   object
#  25  TIPO EGRESO                        6376 non-null   object
#  26  FECHA INGRESO CLINICA              4105 non-null   object
#  27  FECHA INGRESO SERVICIO             4104 non-null   object
#  28  FECHA POSIBLE ALTA                 153 non-null    object
#  29  FECHA ALTA MEDICA                  6376 non-null   object
#  30  FECHA RECAUDO                      1599 non-null   object
#  31  FECHA CAMILLERO                    1836 non-null   object
#  32  FECHA ENFERMERIA                   1453 non-null   object
#  33  FECHA FACTURACION AUDIFARMA        2080 non-null   object
#  34  FECHA FARMACIA                     2061 non-null   object
#  35  FECHA SALIDA                       6376 non-null   object
#  36  FECHA ASEO                         1981 non-null   object
#  37  DEMORA ASIGNACION CAMA             6376 non-null   object
#  38  DEMORA APLICACION MEDICAMENTO      6376 non-null   object
#  39  DEMORA SALIDA CLINICA (DIAS)       6376 non-null   float64
#  40  TRANSFUSION SANGRE                 6376 non-null   object
#  41  ANTIBIOTICO                        6376 non-null   object
#  42  ALTA MEDICA                        6376 non-null   object
#  43  POSIBLE ALTA                       6376 non-null   object
#  44  DXPRINCIPAL EGRESO COD             6376 non-null   object
#  45  DXPRINCIPAL EGRESO                 6376 non-null   object
#  46  DX RELACIONADO1 COD                6357 non-null   object
#  47  DX RELACIONADO1                    6376 non-null   object
#  48  DX RELACIONADO2 COD                6309 non-null   object
#  49  DX RELACIONADO2                    6376 non-null   object
#  50  DX RELACIONADO3 COD                6195 non-null   object
#  51  DX RELACIONADO3                    6376 non-null   object
#  52  TIPO DIAGNOSTICO PRINCIPAL         6376 non-null   object
#  53  PERTINENCIA DIAGNOSTICA            1184 non-null   object
#  54  DX PRINCIPAL EGRESO CATEGORIA COD  6304 non-null   object
#  55  DX PRINCIPAL EGRESO CATEGORIA      6376 non-null   object
#  56  DX PRINCIPAL EGRESO CAPITULO COD   6304 non-null   object
#  57  DX PRINCIPAL EGRESO CAPITULO       6376 non-null   object
#  58  CAUSA BASICA MUERTE COD            566 non-null    object
#  59  CAUSA BASICA MUERTE                6376 non-null   object
#  60  CAUSA BASICA CATEGORIA COD         564 non-null    object
#  61  CAUSA BASICA CATEGORIA             6376 non-null   object
#  62  CAUSA BASICA CAPITULO COD          564 non-null    object
#  63  CAUSA BASICA CAPITULO              6376 non-null   object
#  64  PROFESIONAL ESPECIALIDAD           6376 non-null   object
#  65  PROFESIONAL ESPECIALIDAD GRD       6376 non-null   object
# dtypes: float64(2), int64(4), object(60)
# memory usage: 3.2+ MB
# None
# Variables con  datos nulos:
# FECHA POSIBLE ALTA              6223
# CAUSA BASICA CAPITULO COD       5812
# CAUSA BASICA CATEGORIA COD      5812
# CAUSA BASICA MUERTE COD         5810
# PERTINENCIA DIAGNOSTICA         5192
#                                 ...
# SERVICIO EGRESO                    0
# TIPO EGRESO                        0
# FECHA ALTA MEDICA                  0
# MES                                0
# PROFESIONAL ESPECIALIDAD GRD       0
# Length: 66, dtype: int64

# %%
print("\nPrimeras filas de la base de crónicos:")
print(df_cronicos.head())

print("\nInformación de la base de crónicos:")
print(df_cronicos.info())

# Ordenar las columnas por cantidad de datos nulos de mayor a menor
print("Variables con  datos nulos:")
sorted_null_values = df_cronicos.isnull().sum().sort_values(ascending=False)

# Mostrar los resultados
print(sorted_null_values)
# Out:
# Primeras filas de la base de crónicos:
#    YEAR      MES Fecha diligenciamiento           Hora  AtenciÃ³n  Ingreso  \
# 0  2017  OCTUBRE              2/10/2017  9:00:20 a. m.    3912499  2629714
# 1  2017  OCTUBRE              2/10/2017  9:04:33 a. m.    3942247  2629726
# 2  2017  OCTUBRE              2/10/2017  9:11:43 a. m.    3898560  2629751
# 3  2017  OCTUBRE              2/10/2017  9:33:34 a. m.    3912599  2629828
# 4  2017  OCTUBRE              2/10/2017  9:43:59 a. m.    3906820  2629717
#
#   Tipo  NRODOC  Peso  Talla  ...  Diagnostico79 NombreDiagnostico79  \
# 0   CC  311144  69.0  155.0  ...            NaN                 NaN
# 1   CC  308418  62.0  155.0  ...            NaN                 NaN
# 2   CC  308573  89.0  163.0  ...            NaN                 NaN
# 3   CC  307549  88.0  163.0  ...            NaN                 NaN
# 4   CC  307044  58.0  158.0  ...            NaN                 NaN
#
#    Diagnostico80  NombreDiagnostico80  Diagnostico81  NombreDiagnostico81  \
# 0            NaN                  NaN            NaN                  NaN
# 1            NaN                  NaN            NaN                  NaN
# 2            NaN                  NaN            NaN                  NaN
# 3            NaN                  NaN            NaN                  NaN
# 4            NaN                  NaN            NaN                  NaN
#
#    Diagnostico82  NombreDiagnostico82  Diagnostico83  NombreDiagnostico83
# 0            NaN                  NaN            NaN                  NaN
# 1            NaN                  NaN            NaN                  NaN
# 2            NaN                  NaN            NaN                  NaN
# 3            NaN                  NaN            NaN                  NaN
# 4            NaN                  NaN            NaN                  NaN
#
# [5 rows x 290 columns]
#
# Información de la base de crónicos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38717 entries, 0 to 38716
# Columns: 290 entries, YEAR to NombreDiagnostico83
# dtypes: float64(38), int64(11), object(241)
# memory usage: 85.7+ MB
# None
# Variables con  datos nulos:
# Otras Morbilidades                        38717
# NombreDiagnostico82                       38704
# Diagnostico82                             38704
# NombreDiagnostico83                       38704
# Diagnostico83                             38704
#                                           ...
# CalificaciÃ³n (Apoyo Monopodal)               0
# Tiempo en Segundos (Recorrer 5 metros)        0
# Velocidad (m/s)                               0
# CalificaciÃ³n Velocidad                       0
# YEAR                                          0
# Length: 290, dtype: int64

# %% [markdown]
# #Preprocesamiento

# %% [markdown]
# ##Base Usuarios

# %%
# Vamos a filtrar la base solo con los usuarios que tengan 60 años o más.
df_usuarios60 = df_usuarios[df_usuarios['EDAD'] >= 60]

print("\nInformación de la base de usuarios:")
print(df_usuarios60.info())
# Out:
# Información de la base de usuarios:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130595 entries, 24410 to 183910
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   MES                            130595 non-null  object
#  1   YEAR                           130595 non-null  int64
#  2   NRODOC                         130595 non-null  int64
#  3   SEXO                           130595 non-null  object
#  4   FECHA NACIMIENTO               71743 non-null   object
#  5   EDAD                           130595 non-null  float64
#  6   DEPARTAMENTO                   71631 non-null   object
#  7   MUNICIPIO                      70954 non-null   object
#  8   BARRIO                         96960 non-null   object
#  9   FECHA INICIO AL PGP            109440 non-null  object
#  10  FECHA PRIMERA CLASE FUNCIONAL  76778 non-null   object
#  11  PRIMERA CLASE FUNCIONAL        78149 non-null   object
#  12  FECHA ÚLTIMA CLASE FUNCIONAL   76796 non-null   object
#  13  ÚLTIMA CLASE FUNCIONAL         109546 non-null  object
#  14  CICLO_VITAL                    130595 non-null  object
#  15  QUINQUENIO                     130595 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 16.9+ MB
# None

# %% [markdown]
# Pasamos de 183911 datos a 130595. Ahora como solo nos interesa la información de los usuarios de acuerdo con su edad, vamos a eliminar las variables que tengan datos nulos y nos quedamos con las que estén completas.

# %%
# Eliminar las columnas con datos nulos
df_usuarios60 = df_usuarios60.dropna(axis=1)

# Mostrar las columnas restantes
print(df_usuarios60.columns)
# Out:
# Index(['MES', 'YEAR', 'NRODOC', 'SEXO', 'EDAD', 'CICLO_VITAL', 'QUINQUENIO'], dtype='object')

# %% [markdown]
# Pasamos de 16 variables a 7 y con estas trabajaremos en adelante.

# %% [markdown]
# ##Base Egresos

# %%
# Lo primero es filtrar los registros que correspondan al número de documento de los usuarios que fueron filtrados en la base anterior, que corresponden a edad =>60 años
# Filtrar la base de egresos usando la variable NRODOC de la base usuarios
df_egresos60 = df_egresos[df_egresos['NRODOC'].isin(df_usuarios60['NRODOC'])]

# Verificar el nuevo conjunto de datos
print(df_egresos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5781 entries, 0 to 6375
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   YEAR                               5781 non-null   int64
#  1   MES                                5781 non-null   object
#  2   NRO ATENCION                       5781 non-null   int64
#  3   NRO INGRESO                        5781 non-null   int64
#  4   SERVICIO HABILITADO COD            5781 non-null   float64
#  5   SERVICIO HABILITADO                5781 non-null   object
#  6   TIPO IDENTIFICACION                5781 non-null   object
#  7   NRODOC                             5781 non-null   int64
#  8   FECHA NACIMIENTO                   5781 non-null   object
#  9   REGIMEN AFILIACION                 5781 non-null   object
#  10  EPS VALIDADA                       3736 non-null   object
#  11  MODALIDAD CONTRATO                 5781 non-null   object
#  12  FUENTE FINANCIACION1               5781 non-null   object
#  13  FUENTE FINANCIACION2               5781 non-null   object
#  14  SERVICIO ADMITE                    5781 non-null   object
#  15  BLOQUE ANTERIOR                    5781 non-null   object
#  16  PISO ANTERIOR                      5781 non-null   object
#  17  SERVICIO ANTERIOR                  5781 non-null   object
#  18  NRO CAMA ANTERIOR                  5781 non-null   object
#  19  VIA INGRESO                        5781 non-null   object
#  20  BLOQUE                             5781 non-null   object
#  21  UNIDAD ESTRATEGICA                 5781 non-null   object
#  22  PISO                               5781 non-null   object
#  23  NRO CAMA                           5781 non-null   object
#  24  SERVICIO EGRESO                    5781 non-null   object
#  25  TIPO EGRESO                        5781 non-null   object
#  26  FECHA INGRESO CLINICA              3738 non-null   object
#  27  FECHA INGRESO SERVICIO             3737 non-null   object
#  28  FECHA POSIBLE ALTA                 135 non-null    object
#  29  FECHA ALTA MEDICA                  5781 non-null   object
#  30  FECHA RECAUDO                      1425 non-null   object
#  31  FECHA CAMILLERO                    1668 non-null   object
#  32  FECHA ENFERMERIA                   1294 non-null   object
#  33  FECHA FACTURACION AUDIFARMA        1889 non-null   object
#  34  FECHA FARMACIA                     1863 non-null   object
#  35  FECHA SALIDA                       5781 non-null   object
#  36  FECHA ASEO                         1801 non-null   object
#  37  DEMORA ASIGNACION CAMA             5781 non-null   object
#  38  DEMORA APLICACION MEDICAMENTO      5781 non-null   object
#  39  DEMORA SALIDA CLINICA (DIAS)       5781 non-null   float64
#  40  TRANSFUSION SANGRE                 5781 non-null   object
#  41  ANTIBIOTICO                        5781 non-null   object
#  42  ALTA MEDICA                        5781 non-null   object
#  43  POSIBLE ALTA                       5781 non-null   object
#  44  DXPRINCIPAL EGRESO COD             5781 non-null   object
#  45  DXPRINCIPAL EGRESO                 5781 non-null   object
#  46  DX RELACIONADO1 COD                5774 non-null   object
#  47  DX RELACIONADO1                    5781 non-null   object
#  48  DX RELACIONADO2 COD                5742 non-null   object
#  49  DX RELACIONADO2                    5781 non-null   object
#  50  DX RELACIONADO3 COD                5657 non-null   object
#  51  DX RELACIONADO3                    5781 non-null   object
#  52  TIPO DIAGNOSTICO PRINCIPAL         5781 non-null   object
#  53  PERTINENCIA DIAGNOSTICA            1075 non-null   object
#  54  DX PRINCIPAL EGRESO CATEGORIA COD  5719 non-null   object
#  55  DX PRINCIPAL EGRESO CATEGORIA      5781 non-null   object
#  56  DX PRINCIPAL EGRESO CAPITULO COD   5719 non-null   object
#  57  DX PRINCIPAL EGRESO CAPITULO       5781 non-null   object
#  58  CAUSA BASICA MUERTE COD            489 non-null    object
#  59  CAUSA BASICA MUERTE                5781 non-null   object
#  60  CAUSA BASICA CATEGORIA COD         487 non-null    object
#  61  CAUSA BASICA CATEGORIA             5781 non-null   object
#  62  CAUSA BASICA CAPITULO COD          487 non-null    object
#  63  CAUSA BASICA CAPITULO              5781 non-null   object
#  64  PROFESIONAL ESPECIALIDAD           5781 non-null   object
#  65  PROFESIONAL ESPECIALIDAD GRD       5781 non-null   object
# dtypes: float64(2), int64(4), object(60)
# memory usage: 3.0+ MB
# None

# %% [markdown]
# Pasó de tener 6376 registros a 5781 que corresponden a los usuarios con edad igual o mayor a los 60 años.

# %%
# Verificamos las cantidades de datos nulos por variable
# Ordenar las columnas por cantidad de datos nulos de mayor a menor
print("Variables con  datos nulos:")
sorted_null_values = df_egresos60.isnull().sum().sort_values(ascending=False)

# Mostrar los resultados
print(sorted_null_values)
# Out:
# Variables con  datos nulos:
# FECHA POSIBLE ALTA              5646
# CAUSA BASICA CAPITULO COD       5294
# CAUSA BASICA CATEGORIA COD      5294
# CAUSA BASICA MUERTE COD         5292
# PERTINENCIA DIAGNOSTICA         4706
#                                 ...
# SERVICIO EGRESO                    0
# TIPO EGRESO                        0
# FECHA ALTA MEDICA                  0
# MES                                0
# PROFESIONAL ESPECIALIDAD GRD       0
# Length: 66, dtype: int64

# %%
# TOMAR SOLO LAS VARIABLES A UTILIZAR

df_egresos60 = df_egresos60[['YEAR', 'MES', 'NRO ATENCION', 'NRO INGRESO', 'TIPO IDENTIFICACION', 'NRODOC', 'FECHA NACIMIENTO', 'REGIMEN AFILIACION', 'MODALIDAD CONTRATO',
                             'FUENTE FINANCIACION1','FUENTE FINANCIACION2', 'VIA INGRESO', 'SERVICIO EGRESO', 'TIPO EGRESO', 'FECHA INGRESO CLINICA', 'FECHA INGRESO SERVICIO',
                             'FECHA SALIDA', 'DEMORA SALIDA CLINICA (DIAS)','TIPO DIAGNOSTICO PRINCIPAL']]
# Verificar el nuevo conjunto de datos
print(df_egresos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5781 entries, 0 to 6375
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   YEAR                          5781 non-null   int64
#  1   MES                           5781 non-null   object
#  2   NRO ATENCION                  5781 non-null   int64
#  3   NRO INGRESO                   5781 non-null   int64
#  4   TIPO IDENTIFICACION           5781 non-null   object
#  5   NRODOC                        5781 non-null   int64
#  6   FECHA NACIMIENTO              5781 non-null   object
#  7   REGIMEN AFILIACION            5781 non-null   object
#  8   MODALIDAD CONTRATO            5781 non-null   object
#  9   FUENTE FINANCIACION1          5781 non-null   object
#  10  FUENTE FINANCIACION2          5781 non-null   object
#  11  VIA INGRESO                   5781 non-null   object
#  12  SERVICIO EGRESO               5781 non-null   object
#  13  TIPO EGRESO                   5781 non-null   object
#  14  FECHA INGRESO CLINICA         3738 non-null   object
#  15  FECHA INGRESO SERVICIO        3737 non-null   object
#  16  FECHA SALIDA                  5781 non-null   object
#  17  DEMORA SALIDA CLINICA (DIAS)  5781 non-null   float64
#  18  TIPO DIAGNOSTICO PRINCIPAL    5781 non-null   object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 903.3+ KB
# None

# %% [markdown]
# Pasamos de 63 variables a 19. Ahora vamos a tratar los datos nulos que quedan en estas variables, para ello se eliminan las filas que poseen datos nulos, ya que justamente son las que indican la fecha de ingreso a la clínica y al servicio, por lo que es imprescindible tener la información. Aquí se pasaría entonces a tener 3737 registros, es decir, se perdería el 35.3% de los registros.

# %%
# Eliminar filas con datos nulos
df_egresos60 = df_egresos60.dropna()

# Verificar el nuevo conjunto de datos
print(df_egresos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3737 entries, 2 to 6375
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   YEAR                          3737 non-null   int64
#  1   MES                           3737 non-null   object
#  2   NRO ATENCION                  3737 non-null   int64
#  3   NRO INGRESO                   3737 non-null   int64
#  4   TIPO IDENTIFICACION           3737 non-null   object
#  5   NRODOC                        3737 non-null   int64
#  6   FECHA NACIMIENTO              3737 non-null   object
#  7   REGIMEN AFILIACION            3737 non-null   object
#  8   MODALIDAD CONTRATO            3737 non-null   object
#  9   FUENTE FINANCIACION1          3737 non-null   object
#  10  FUENTE FINANCIACION2          3737 non-null   object
#  11  VIA INGRESO                   3737 non-null   object
#  12  SERVICIO EGRESO               3737 non-null   object
#  13  TIPO EGRESO                   3737 non-null   object
#  14  FECHA INGRESO CLINICA         3737 non-null   object
#  15  FECHA INGRESO SERVICIO        3737 non-null   object
#  16  FECHA SALIDA                  3737 non-null   object
#  17  DEMORA SALIDA CLINICA (DIAS)  3737 non-null   float64
#  18  TIPO DIAGNOSTICO PRINCIPAL    3737 non-null   object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 583.9+ KB
# None

# %%
# Convertir columnas de fecha al tipo datetime
df_egresos60['FECHA NACIMIENTO'] = pd.to_datetime(df_egresos60['FECHA NACIMIENTO'])
df_egresos60['FECHA SALIDA'] = pd.to_datetime(df_egresos60['FECHA SALIDA'])
df_egresos60['FECHA INGRESO SERVICIO'] = pd.to_datetime(df_egresos60['FECHA INGRESO SERVICIO'])

# Calcular el tiempo de estancia hospitalaria
df_egresos60['TIEMPO ESTANCIA (DIAS)'] = (df_egresos60['FECHA SALIDA'] - df_egresos60['FECHA INGRESO SERVICIO']).dt.days

# Convertir columnas numéricas a int
columnas_numericas = ['NRO ATENCION', 'NRO INGRESO', 'NRODOC']
df_egresos60[columnas_numericas] = df_egresos60[columnas_numericas].astype(int)

# Verificar el nuevo conjunto de datos
print(df_egresos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3737 entries, 2 to 6375
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   YEAR                          3737 non-null   int64
#  1   MES                           3737 non-null   object
#  2   NRO ATENCION                  3737 non-null   int64
#  3   NRO INGRESO                   3737 non-null   int64
#  4   TIPO IDENTIFICACION           3737 non-null   object
#  5   NRODOC                        3737 non-null   int64
#  6   FECHA NACIMIENTO              3737 non-null   datetime64[ns]
#  7   REGIMEN AFILIACION            3737 non-null   object
#  8   MODALIDAD CONTRATO            3737 non-null   object
#  9   FUENTE FINANCIACION1          3737 non-null   object
#  10  FUENTE FINANCIACION2          3737 non-null   object
#  11  VIA INGRESO                   3737 non-null   object
#  12  SERVICIO EGRESO               3737 non-null   object
#  13  TIPO EGRESO                   3737 non-null   object
#  14  FECHA INGRESO CLINICA         3737 non-null   object
#  15  FECHA INGRESO SERVICIO        3737 non-null   datetime64[ns]
#  16  FECHA SALIDA                  3737 non-null   datetime64[ns]
#  17  DEMORA SALIDA CLINICA (DIAS)  3737 non-null   float64
#  18  TIPO DIAGNOSTICO PRINCIPAL    3737 non-null   object
#  19  TIEMPO ESTANCIA (DIAS)        3737 non-null   int64
# dtypes: datetime64[ns](3), float64(1), int64(5), object(11)
# memory usage: 613.1+ KB
# None

# %% [markdown]
# ##Base Crónicos

# %%
# Analizamos que hay en la base de datos.
df_cronicos.head(10)
# Out:
#    YEAR      MES Fecha diligenciamiento            Hora  AtenciÃ³n  Ingreso  \
# 0  2017  OCTUBRE              2/10/2017   9:00:20 a. m.    3912499  2629714
# 1  2017  OCTUBRE              2/10/2017   9:04:33 a. m.    3942247  2629726
# 2  2017  OCTUBRE              2/10/2017   9:11:43 a. m.    3898560  2629751
# 3  2017  OCTUBRE              2/10/2017   9:33:34 a. m.    3912599  2629828
# 4  2017  OCTUBRE              2/10/2017   9:43:59 a. m.    3906820  2629717
# 5  2017  OCTUBRE              2/10/2017   9:51:22 a. m.    3935619  2629892
# 6  2017  OCTUBRE              2/10/2017   9:59:17 a. m.    3941021  2629907
# 7  2017  OCTUBRE             11/10/2017   3:27:42 p. m.    3952389  2640869
# 8  2017  OCTUBRE              2/10/2017  10:19:11 a. m.    3912623  2629716
# 9  2017  OCTUBRE              2/10/2017  10:23:56 a. m.    3897898  2629989
#
#   Tipo  NRODOC  Peso  Talla  ...  Diagnostico79 NombreDiagnostico79  \
# 0   CC  311144  69.0  155.0  ...            NaN                 NaN
# 1   CC  308418  62.0  155.0  ...            NaN                 NaN
# 2   CC  308573  89.0  163.0  ...            NaN                 NaN
# 3   CC  307549  88.0  163.0  ...            NaN                 NaN
# 4   CC  307044  58.0  158.0  ...            NaN                 NaN
# 5   CC  309419  53.0  146.0  ...            NaN                 NaN
# 6   CC  308437  43.0  139.0  ...            NaN                 NaN
# 7   CC  308437  43.0  138.0  ...            NaN                 NaN
# 8   CC  308637  55.0  158.0  ...            NaN                 NaN
# 9   CC  308561  71.0  160.0  ...            NaN                 NaN
#
#    Diagnostico80  NombreDiagnostico80  Diagnostico81  NombreDiagnostico81  \
# 0            NaN                  NaN            NaN                  NaN
# 1            NaN                  NaN            NaN                  NaN
# 2            NaN                  NaN            NaN                  NaN
# 3            NaN                  NaN            NaN                  NaN
# 4            NaN                  NaN            NaN                  NaN
# 5            NaN                  NaN            NaN                  NaN
# 6            NaN                  NaN            NaN                  NaN
# 7            NaN                  NaN            NaN                  NaN
# 8            NaN                  NaN            NaN                  NaN
# 9            NaN                  NaN            NaN                  NaN
#
#    Diagnostico82  NombreDiagnostico82  Diagnostico83  NombreDiagnostico83
# 0            NaN                  NaN            NaN                  NaN
# 1            NaN                  NaN            NaN                  NaN
# 2            NaN                  NaN            NaN                  NaN
# 3            NaN                  NaN            NaN                  NaN
# 4            NaN                  NaN            NaN                  NaN
# 5            NaN                  NaN            NaN                  NaN
# 6            NaN                  NaN            NaN                  NaN
# 7            NaN                  NaN            NaN                  NaN
# 8            NaN                  NaN            NaN                  NaN
# 9            NaN                  NaN            NaN                  NaN
#
# [10 rows x 290 columns]

# %%
df_cronicos.dtypes
# Out:
# YEAR                       int64
# MES                       object
# Fecha diligenciamiento    object
# Hora                      object
# AtenciÃ³n                  int64
#                            ...
# NombreDiagnostico81       object
# Diagnostico82             object
# NombreDiagnostico82       object
# Diagnostico83             object
# NombreDiagnostico83       object
# Length: 290, dtype: object

# %%
nombres_columnas = df_cronicos.columns.tolist()
print(nombres_columnas)
# Out:
# ['YEAR', 'MES', 'Fecha diligenciamiento', 'Hora', 'AtenciÃ³n', 'Ingreso', 'Tipo', 'NRODOC', 'Peso', 'Talla', 'IMC', 'ClasificaciÃ³n IMC', 'SaturaciÃ³n de OxÃ\xadgeno (%)', 'PerÃ\xadmetro Muslo', 'PerÃ\xadmetro Cintura', 'Pliegue Triceps', 'Pliegue Abdomen', 'Pliegue Muslo', 'Sumatoria Pliegues', 'PresiÃ³n Arterial SistÃ³lica', 'PresiÃ³n Arterial DiastÃ³lica', 'Frecuencia CardÃ\xadaca en reposo', 'Auto-calificacion Nivel de Ejercicio', 'Constantes', 'METS -Ã\x8dndice MetabÃ³lico', 'VO2 - MÃ¡xima Cantidad de OxÃ\xadgeno', 'Ã\x8dndice de Fragilidad Groningen', 'CalificaciÃ³n (Ã\x8dndice de Fragilidad)', 'Tiempo en Segundos (Apoyo Monopodal)', 'CalificaciÃ³n (Apoyo Monopodal)', 'Tiempo en Segundos (Recorrer 5 metros)', 'Velocidad (m/s)', 'CalificaciÃ³n Velocidad', 'Test Findrisc', 'Ã\x8dndice Tob
6', 'Diagnostico7', 'NombreDiagnostico7', 'Diagnostico8', 'NombreDiagnostico8', 'Diagnostico9', 'NombreDiagnostico9', 'Diagnostico10', 'NombreDiagnostico10', 'Diagnostico11', 'NombreDiagnostico11', 'Diagnostico12', 'NombreDiagnostico12', 'Diagnostico13', 'NombreDiagnostico13', 'Diagnostico14', 'NombreDiagnostico14', 'Diagnostico15', 'NombreDiagnostico15', 'Diagnostico16', 'NombreDiagnostico16', 'Diagnostico17', 'NombreDiagnostico17', 'Diagnostico18', 'NombreDiagnostico18', 'Diagnostico19', 'NombreDiagnostico19', 'Diagnostico20', 'NombreDiagnostico20', 'Diagnostico21', 'NombreDiagnostico21', 'Diagnostico22', 'NombreDiagnostico22', 'Diagnostico23', 'NombreDiagnostico23', 'Diagnostico24', 'NombreDiagnostico24', 'Diagnostico25', 'NombreDiagn ...

# %%
# Lo primero es filtrar los registros que correspondan al número de documento de los usuarios que fueron filtrados en la base usuarios, que corresponden a edad =>60 años
# Filtrar la base de cronicos usando la variable NRODOC de la base usuarios
df_cronicos60 = df_cronicos[df_cronicos['NRODOC'].isin(df_usuarios60['NRODOC'])]

# Verificar el nuevo conjunto de datos
print(df_cronicos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35055 entries, 0 to 38716
# Columns: 290 entries, YEAR to NombreDiagnostico83
# dtypes: float64(38), int64(11), object(241)
# memory usage: 77.8+ MB
# None

# %% [markdown]
# Pasó de tener 38717 registros a 35055 que corresponden a los usuarios con edad igual o mayor a los 60 años.

# %%
# Verificamos las cantidades de datos nulos por variable
# Ordenar las columnas por cantidad de datos nulos de mayor a menor
print("Variables con  datos nulos:")
sorted_null_values = df_cronicos60.isnull().sum().sort_values(ascending=False)

# Mostrar los resultados
print(sorted_null_values)
# Out:
# Variables con  datos nulos:
# Otras Morbilidades                        35055
# NombreDiagnostico82                       35042
# Diagnostico82                             35042
# NombreDiagnostico83                       35042
# Diagnostico83                             35042
#                                           ...
# CalificaciÃ³n (Apoyo Monopodal)               0
# Tiempo en Segundos (Recorrer 5 metros)        0
# Velocidad (m/s)                               0
# CalificaciÃ³n Velocidad                       0
# YEAR                                          0
# Length: 290, dtype: int64

# %%
##########################Evaluar si aplicarlo o no, pasaría de tener 290 variables a  tener 72#################
# ELIMINAR LAS VARIABLES (COLUMNAS) CON MÁS DEL 20% DE DATOS NULOS
#Calcular el porcentaje de datos nulos por columna
nulos_por_columna = df_cronicos60.isnull().sum() / len(df_cronicos60) * 100

# Seleccionar las columnas con más del 20% de datos nulos
columnas_eliminar = nulos_por_columna[nulos_por_columna > 20].index

# Eliminar las columnas seleccionadas del DataFrame
df_cronicos60 = df_cronicos60.drop(columns=columnas_eliminar)

# Verificar el nuevo conjunto de datos
print(df_cronicos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35055 entries, 0 to 38716
# Data columns (total 72 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0
#  60  Microalbuminuria                           34100 non-null  float64
#  61  Fecha microalbuminuria                     31140 non-null  object
#  62  Hormona Estimulante de la Tiroides (TSH)   34100 non-null  float64
#  63  Clase Funcional                            34100 non-null  object
#  64  Creatinina 2 consulta                      34100 non-null  float64
#  65  Tasa de FiltraciÃ³n Glomerular TFG2        34100 non-null  float64
#  66  Meses de diferencia entre TFG              34100 non-null  float64
#  67  Cambio de TFG                              34100 non-null  float64
#  68  Ãlcera de pie diabÃ©tico                  32371 non-null  object
#  69  RemisiÃ³n                                  34100 non-null  object
#  70  DiagnÃ³stico Principal                     33824 non-null  object
#  71  AnÃ¡lisis y conducta a seguir              34098 non-null  object
# dtypes: float64(28), int64(11), object(33)
# memory usage: 19.5+ MB
# None

# %% [markdown]
# Pasamos de 290 variables a 72. Ahora verificamos las variables de fechas.

# %%
# Verificar la forma de los datos de las variables de fechas para aplicar formato
print(df_cronicos60[['Fecha diligenciamiento','Hora','Fecha glicemia','Fecha hemoglobina glicosilada','Fecha HDL',
                     'Fecha colesterol total','Fecha trigliceridos','Fecha creatinina1','Fecha microalbuminuria']])
# Out:
#       Fecha diligenciamiento           Hora   Fecha glicemia  \
# 0                  2/10/2017  9:00:20 a. m.               ND
# 1                  2/10/2017  9:04:33 a. m.               ND
# 2                  2/10/2017  9:11:43 a. m.               ND
# 3                  2/10/2017  9:33:34 a. m.               ND
# 4                  2/10/2017  9:43:59 a. m.               ND
# ...                      ...            ...              ...
# 38712             31/05/2022  10:55:31 p.m.   2/09/2021 0:00
# 38713             31/05/2022  10:59:58 p.m.  12/10/2021 0:00
# 38714             31/05/2022  11:13:57 p.m.   9/09/2021 0:00
# 38715             31/05/2022  11:17:35 p.m.   9/02/2022 0:00
# 38716             31/05/2022  11:25:39 p.m.   7/04/2022 0:00
#
#       Fecha hemoglobina glicosilada        Fecha HDL Fecha colesterol total  \
# 0                                ND               ND                     ND
# 1                                ND               ND                     ND
# 2                                ND               ND                     ND
# 3                                ND               ND                     ND
# 4                                ND               ND                     ND
# ...                             ...              ...                    ...
# 38712                2/09/2021 0:00   2/09/2021 0:00         2/09/2021 0:00
# 38713               25/03/2022 0:00  25/03/2022 0:00        25/03/2022 0:00
# 38714                9/09/2021 0:00   9/09/2021 0:00         9/09/2021 0:00
# 38715                9/02/2022 0:00   9/02/2022 0:00         9/02/2022 0:00
# 38716                7/04/2022 0:00   7/04/2022 0:00         7/04/2022 0:00
#
#       Fecha trigliceridos Fecha creatinina1 Fecha microalbuminuria
# 0                      ND                ND                     ND
# 1                      ND                ND                     ND
# 2                      ND                ND                     ND
# 3                      ND                ND                     ND
# 4                      ND                ND                     ND
# ...                   ...               ...                    ...
# 38712      2/09/2021 0:00   15/09/2021 0:00        31/07/2021 0:00
# 38713     25/03/2022 0:00   25/03/2022 0:00        25/03/2022 0:00
# 38714      9/09/2021 0:00    9/09/2021 0:00         9/09/2021 0:00
# 38715      9/02/2022 0:00    9/02/2022 0:00         6/10/2021 0:00
# 38716      7/04/2022 0:00    7/04/2022 0:00        24/11/2021 0:00
#
# [35055 rows x 9 columns]

# %%
# Como las variables 'Fecha glicemia','Fecha hemoglobina glicosilada','Fecha HDL','Fecha colesterol total','Fecha trigliceridos','Fecha creatinina1','Fecha microalbuminuria'
# no contienen realmente datos, se procede a eliminar dichas columnas.

columns_to_drop = ['Fecha glicemia', 'Fecha hemoglobina glicosilada',
                   'Fecha HDL', 'Fecha colesterol total', 'Fecha trigliceridos', 'Fecha creatinina1',
                   'Fecha microalbuminuria']

df_cronicos60.drop(columns=columns_to_drop, inplace=True)

#Quedamos con 65 variables
# Out:
# <ipython-input-63-b20e89284a2b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cronicos60.drop(columns=columns_to_drop, inplace=True)

# %%
df_cronicos60.isnull().sum()

#nombres_columnas = df_cronicos.columns.tolist()
#print(nombres_columnas)
# Out:
# YEAR                          0
# MES                           0
# Fecha diligenciamiento        0
# Hora                          0
# AtenciÃ³n                     0
#                           ...
# NombreDiagnostico81       35040
# Diagnostico82             35042
# NombreDiagnostico82       35042
# Diagnostico83             35042
# NombreDiagnostico83       35042
# Length: 283, dtype: int64

# %% [markdown]
# Ahora vamos a tratar los datos nulos que quedan en estas variables, para ello se eliminan las filas que poseen datos nulos.

# %%
# Eliminar filas con datos nulos #################DEFINIR SI LO HACEMOS O NO, SE PIERDE EL 32.7% DE LOS REGISTROS.
df_cronicos60 = df_cronicos60.dropna()

# Verificar el nuevo conjunto de datos
print(df_cronicos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26322 entries, 0 to 38716
# Data columns (total 65 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   YEAR                                       26322 non-null  int64
#  1   MES                                        26322 non-null  object
#  2   Fecha diligenciamiento                     26322 non-null  object
#  3   Hora                                       26322 non-null  object
#  4   AtenciÃ³n                                  26322 non-null  int64
#  5   Ingreso                                    26322 non-null  int64
#  6   Tipo                                       26322 non-null  object
#  7   NRODOC                                     26322 non-null  int64
#  8   Peso                                       26322 non-null  float64
#  9   Talla                                      26322 non-null  float64
#  10  IMC                                        26322 non-null  float64
#  11  ClasificaciÃ³n IMC                         26322 non-null  object
#  12  SaturaciÃ³n de OxÃ­geno (%)                26322 non-null  float64
#  13  PerÃ­metro Muslo                           26322 non-null  int64
#  14  PerÃ­metro Cintura                         26322 non-null  float64
#  15  Pliegue Triceps                            26322 non-null  float64
#  16  Pliegue Abdomen                            26322 non-null  float64
#  17  Pliegue Muslo                              26322 non-null  float64
#  18  Sumatoria Pliegues                         26322 non-null  float64
#  19  PresiÃ³n Arterial SistÃ³lica               26322 non-null  int64
#  20  PresiÃ³n Arterial DiastÃ³lica              26322 non-null  int64
#  21  Frecuencia CardÃ­aca en reposo             26322 non-null  int64
#  22  Auto-calificacion Nivel de Ejercicio       26322 non-null  int64
#  23  Constantes                                 26322 non-null  float64
#  24  METS -Ãndice MetabÃ³lico                  26322 non-null  float64
#  25  VO2 - MÃ¡xima Cantidad de OxÃ­geno         26322 non-null  float64
#  26  Ãndice de Fragilidad Groningen            26322 non-null  float64
#  27  CalificaciÃ³n (Ãndice de Fragilidad)      26322 non-null  object
#  28  Tiempo en Segundos (Apoyo Monopodal)       26322 non-null  int64
#  29  CalificaciÃ³n (Apoyo Monopodal)            26322 non-null  object
#  30  Tiempo en Segundos (Recorrer 5 metros)     26322 non-null  int64
#  31  Velocidad (m/s)                            26322 non-null  float64
#  32  CalificaciÃ³n Velocidad                    26322 non-null  object
#  33  Diabetes Mellitus                          26322 non-null  object
#  34  Glicemia                                   26322 non-null  float64
#  35  Hemoglobina Glicada                        26322 non-null  float64
#  36  Control Diabetes                           26322 non-null  object
#  37  Tiene HTA                                  26322 non-null  object
#  38  Tiempo con el diagnÃ³stico1                26322 non-null  object
#  39  Tiene EPOC                                 26322 non-null  object
#  40  Enfermedad Coronaria (En el Ãºltimo aÃ±o)  26322 non-null  object
#  41  Insuficiencia CardÃ­aca                    26322 non-null  object
#  42  ValvulopatÃ­a                              26322 non-null  object
#  43  Arritmia o paciente con dispositivo        26322 non-null  object
#  44  Sufre de alguna enfermedad cardiovascular  26322 non-null  object
#  45  Tabaquismo                                 26322 non-null  object
#  46  Cuantos cigarrillos dÃ­a                   26322 non-null  object
#  47  Lipoproteina                               26322 non-null  float64
#  48  HDL                                        26322 non-null  float64
#  49  Colesterol total                           26322 non-null  float64
#  50  Trigliceridos                              26322 non-null  float64
#  51  Creatinina 1 consulta                      26322 non-null  float64
#  52  Tasa de FiltraciÃ³n Glomerular TFG         26322 non-null  float64
#  53  Estadio de la Enfermedad Renal             26322 non-null  object
#  54  Microalbuminuria                           26322 non-null  float64
#  55  Hormona Estimulante de la Tiroides (TSH)   26322 non-null  float64
#  56  Clase Funcional                            26322 non-null  object
#  57  Creatinina 2 consulta                      26322 non-null  float64
#  58  Tasa de FiltraciÃ³n Glomerular TFG2        26322 non-null  float64
#  59  Meses de diferencia entre TFG              26322 non-null  float64
#  60  Cambio de TFG                              26322 non-null  float64
#  61  Ãlcera de pie diabÃ©tico                  26322 non-null  object
#  62  RemisiÃ³n                                  26322 non-null  object
#  63  DiagnÃ³stico Principal                     26322 non-null  object
#  64  AnÃ¡lisis y conducta a seguir              26322 non-null  object
# dtypes: float64(28), int64(11), object(26)
# memory usage: 13.3+ MB
# None

# %% [markdown]
# Se pasa de 35055 registros a 23563, perdiendo el 32.7% de los datos.

# %%
#Ajustar formatos de fechas
#df_cronicos60['Fecha diligenciamiento'] = pd.to_datetime(df_cronicos60['Fecha diligenciamiento'])
#df_cronicos60['Hora'] = pd.to_datetime(df_cronicos60['Hora'])
# Verificar el nuevo conjunto de datos
#print(df_cronicos60.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c0a605c79254> in <cell line: 2>()
#       1 #Ajustar formatos de fechas
# ----> 2 df_cronicos60['Fecha diligenciamiento'] = pd.to_datetime(df_cronicos60['Fecha diligenciamiento'])
#       3 df_cronicos60['Hora'] = pd.to_datetime(df_cronicos60['Hora'])
#       4 # Verificar el nuevo conjunto de datos
#       5 print(df_cronicos60.info())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044                 result = arg.tz_localize("utc")
#    1045     elif isinstance(arg, ABCSeries):
# -> 1046         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047         if not cache_array.empty:
#    1048             result = arg.map(cache_array)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     248         unique_dates = unique(arg)
#     249         if len(unique_dates) < len(arg):
# --> 250             cache_dates = convert_listlike(unique_dates, format)
#     251             # GH#45319
#     252             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452     if format is not None and format != "mixed":
# --> 453         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     454
#     455     result, tz_parsed = objects_to_datetime64ns(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "31/10/2017" doesn't match format "%m/%d/%Y", at position 2. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
#Renombramos algunas columnas que tienen problemas con la escritura

df_cronicos60.rename(columns={'AtenciÃ³n': 'Atencion'}, inplace=True)
df_cronicos60.rename(columns={'ClasificaciÃ³n IMC': 'Clasificacion IMC'}, inplace=True)
df_cronicos60.rename(columns={'SaturaciÃ³n de OxÃ­geno (%)': 'Saturacion de oxigeno'}, inplace=True)
df_cronicos60.rename(columns={'PerÃ­metro Muslo': 'Perimetro muslo'}, inplace=True)
df_cronicos60.rename(columns={'PerÃ­metro Cintura': 'Perimetro cintura'}, inplace=True)
df_cronicos60.rename(columns={'PresiÃ³n Arterial SistÃ³lica': 'Presion arterial sistolica'}, inplace=True)
df_cronicos60.rename(columns={'PresiÃ³n Arterial DiastÃ³lica ': 'Presion arterial diastolica'}, inplace=True)
df_cronicos60.rename(columns={'METS -Ãndice MetabÃ³lico': 'METS indice metabolico'}, inplace=True)
df_cronicos60.rename(columns={'VO2 - MÃ¡xima Cantidad de OxÃ­geno': 'VO2 Maxima cantidad de oxigeno'}, inplace=True)
df_cronicos60.rename(columns={'Ãndice de Fragilidad Groningen': 'Indice de fragilidad groningen'}, inplace=True)
df_cronicos60.rename(columns={'CalificaciÃ³n (Ãndice de Fragilidad)': 'Calificacion indice de fragilidad'}, inplace=True)
df_cronicos60.rename(columns={'CalificaciÃ³n (Apoyo Monopodal)': 'Calificacion apoyo monopodal'}, inplace=True)
df_cronicos60.rename(columns={'CalificaciÃ³n Velocidad': 'Calificacion velocidad'}, inplace=True)
df_cronicos60.rename(columns={'Tiempo con el diagnÃ³stico1': 'Tiempo con el diagnostico1'}, inplace=True)
df_cronicos60.rename(columns={'Enfermedad Coronaria (En el Ãºltimo aÃ±o)': 'Enermedad coronaria en el ultimo año'}, inplace=True)
df_cronicos60.rename(columns={'Insuficiencia CardÃ­aca': 'Insuficiencia cardiaca'}, inplace=True)
df_cronicos60.rename(columns={'ValvulopatÃ­a': 'Valvulopatia'}, inplace=True)
df_cronicos60.rename(columns={'Cuantos cigarrillos dÃ­a': 'Cuantos cigarrillos al dia'}, inplace=True)
df_cronicos60.rename(columns={'Tasa de FiltraciÃ³n Glomerular TFG': 'Tasa de filtracion glomerular TFG'}, inplace=True)
df_cronicos60.rename(columns={'Tasa de FiltraciÃ³n Glomerular TFG2': 'Tasa de filtracion glomerular TFG2'}, inplace=True)
df_cronicos60.rename(columns={'Ãlcera de pie diabÃ©tico': 'Ulcera de pie diabetico'}, inplace=True)
df_cronicos60.rename(columns={'RemisiÃ³n': 'Remision'}, inplace=True)
df_cronicos60.rename(columns={'DiagnÃ³stico Principal': 'Diagnostico principal'}, inplace=True)
df_cronicos60.rename(columns={'AnÃ¡lisis y conducta a seguir': 'Analisis y conducta a seguir'}, inplace=True)

# Verificamos
print(df_cronicos60.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 
#  1.8400e+02 1.8600e+02 1.9100e+02 1.0800e+02 1.1900e+02 1.0000e+02]
# ------------------------------------------------------
# Valores únicos para IMC:
# [28.72 25.81 33.5  ... 32.16 16.16 46.47]
# ------------------------------------------------------
# Valores únicos para Clasificacion IMC:
# ['Sobrepeso' 'Obesidad Grasa' 'Normal' 'Bajo']
# ------------------------------------------------------
# Valores únicos para Saturacion de oxigeno:
# [ 91.  94.  96.  73.  97.  88.  95.  93.  92.  98.  86.   0.  82.  90.
#   84.  89.  87.  80.  79.  83.  99. 100.  69.  75.  85.  64.  78.  81.
#   76.  74.  68.  77.  70.  72.  71.  67.  63.  65.   9.  62.  66. 891.
#  105.  59. 114. 111.  10.  60. 115.  58. 598.  61.  57.  54.  51.]
# ------------------------------------------------------
# Valores únicos para Perimetro muslo:
# [  51   60   65   66   59   55   49   75   57   62  104   58   67   46
#    54   56   61   53   48   69   50   63   52   73   70   64   47   68
#    40   45   93   44   38   41   42   71   39   43   74  110   82   76
#    37   80   72   21   77   79   78   81   97  109  106   86  130   90
#    87   88   89  116  114  111   96   95   34   84   35   92  162   94
#   129  132  458  131   99  108   91   83  121   85  126   33  105   27
#   122  133  152   31   36  123  118   11  102  103   15  120    8   20
#    22   32   25   24   28   23   30    5  128  100    0   18  690 5730
#    16  580   29   26]
# ------------------------------------------------------
# Valores únicos para Perimetro cintura:
# [1.0900e+02 8.9000e+01 1.1300e+02 1.0800e+02 9.0000e+01 8.8000e+01
#  1.0000e+02 1.2300e+02 1.0600e+02 9.9000e+01 5.6000e+01 9.4000e+01
#  1.1000e+02 1.1200e+02 1.0700e+02 1.0300e+02 7.9000e+01 9.8000e+01
#  1.1100e+02 1.1600e+02 8.7000e+01 9.7000e+01 1.0200e+02 8.5000e+01
#  9.5000e+01 1.0500e+02 1.0100e+02 1.2400e+02 9.2000e+01 1.1700e+02
#  1.2600e+02 1.1900e+02 1.3400e+02 9.1000e+01 9.6000e+01 7.7000e+01
#  9.3000e+01 1.0400e+02 1.3600e+02 8.6000e+01 1.4000e+02 6.9000e+01
#  8.0000e+01 1.1500e+02 1.3000e+02 8.2000e+01 1.1800e+02 8.4000e+01
#  1.1400e+02 5.2000e+01 7.8000e+01 8.3000e+01 1.2500e+02 7.6000e+01
#  8.1000e+01 7.2000e+01 1.2000e+02 1.4000e+00 7.5000e+01 1.2200e+02
#  7.1000e+01 1.2100e+02 1.3100e+02 1.3200e+02 1.3900e+02 7.4000e+01
#  1.2900e+02 1.2700e+02 1.3300e+02 1.2800e+02 1.4300e+02 1.4700e+02
#  1.1000e+01 1.5100e+02 1.4800e+02 7.0000e+01 1.3500e+02 1.4600e+02
#  1.3700e+02 5.0000e+01 1.5500e+02 1.4200e+02 6.2000e+01 1.4100e+02
#  5.4000e+01 6.5000e+01 5.3000e+01 1.9000e+02 3.9000e+01 4.2000e+01
#  4.4000e+01 5.9000e+01 5.8000e+01 1.4400e+02 6.0000e+01 6.8000e+01
#  1.0990e+03 5.1000e+01 4.9000e+01 4.7000e+01 4.8000e+01 7.3000e+01
#  '4' '19' '23' '12' '9' '26' '40' '10' '27' '17' '34' '5' '24' '6' '3'
#  '44' '32' '7' '47' '18' '51' '41' '30' '8' '28' '37' '2' 13.0 21.0 11.0
#  49.0 22.0 16.0 9.0 41.0 14.0 19.0 6.0 5.0 43.0 33.0 15.0 4.0 3.0 46.0 1.0
#  29.0 7.0 12.0 31.0 36.0 26.0 23.0 2.0 20.0 10.0 24.0 18.0 32.0 44.0 25.0
#  8.0 27.0 17.0 51.0 42.0 40.0 37.0 47.0 52.0 45.0 28.0 34.0 30.0 39.0 54.0
#  38.0 35.0 55.0 121.0 0.0 2021.0 56.0 122.0 50.0 53.0]
# ------------------------------------------------------
# Valores únicos para Tiene EPOC:
# ['No' 'Si' 'Sospecha' 'EPOC no espirometrico']
# ------------------------------------------------------
# Valores únicos para Enermedad coronaria en el ultimo año:
# ['No aplica' 'IAM' 'Angina estable' 'Angina inestable' 'No']
# ------------------------------------------------------
# Valores únicos para Insuficiencia cardiaca:
# ['No aplica' 'Controlada' 'No controlada' 'Signos de sobrecarga'
#  'Deterioro de c. funcional' 'No']
# ------------------------------------------------------
# Valores únicos para Valvulopatia:
# ['No' 'Si']
# ------------------------------------------------------
# Valores únicos para Arritmia o paciente con dispositivo:
# ['No' 'Si']
# ------------------------------------------------------
# Valores únicos para Sufre de alguna enfermedad cardiovascular:
# ['No' 'Si']
# ------------------------------------------------------
# Valores únicos para Tabaquismo:
# ['Si' 'No' 'Ex-fumador']
# ------------------------------------------------------
# Valores únicos para Cuantos cigarrillos al dia:
# ['ND' '0' '5' '20' '1' '30' '10' '8' '6' '3' '40' '50' '4' '35' '11' '2'
#  '9' '15' '7' 10.0 0.0 40.0 3.0 12.0 20.0 5.0 30.0 7.0 8.0 1.0 15.0 50.0
#  2.0 35.0 4.0 9.0 11.0 6.0 60.0 25.0 205.0]
# ------------------------------------------------------
# Valores únicos para Lipoproteina:
# [60.68 92.   43.   ... 80.66 43.97 53.37]
# ------------------------------------------------------
# Valores únicos para HDL:
# [53.95 45.   30.   ... 59.43 14.8  33.42]
# ------------------------------------------------------
# Valores únicos para Colesterol total:
# [128.   157.   115.   ... 118.56  36.81  98.54]
# ------------------------------------------------------
# Valores únicos para Trigliceridos:
# [ 67.33 103.   204.   ...  75.12 326.4  248.89]
# ------------------------------------------------------
# Valores únicos para Creatinina 1 consulta:
# [6.800e-01 8.500e-01 1.320e+00 1.000e+00 1.390e+00 9.900e-01 6.500e-01
#  1.310e+00 1.340e+00 6.700e-01 9.300e-01 8.000e-01 8.100e-01 9.200e-01
#  7.700e-01 7.500e-01 6.600e-01 7.300e-01 1.560e+00 6.000e-01 1.240e+00
#  1.090e+00 1.300e+00 1.230e+00 1.100e+00 6.300e-01 7.800e-01 5.200e-01
#  7.000e-01 7.400e-01 1.080e+00 9.600e-01 1.110e+00 1.260e+00 1.210e+00
#  1.200e+00 8.800e-01 8.700e-01 8.900e-01 1.550e+00 5.900e-01 9.700e-01
#  9.400e-01 1.160e+00 1.820e+00 8.600e-01 1.360e+00 1.700e+00 1.460e+00
#  3.100e+00 1.149e+01 2.460e+00 2.610e+00 2.960e+00 5.480e+00 1.930e+00
#  2.900e-01 3.300e+00 2.420e+00 2.600e-01 3.050e+00 4.300e-01 3.100e-01
#  2.500e-01 8.760e+00 3.450e+00 2.810e+00 5.310e+00 3.030e+00 7.680e+00
# ...
#  'I255 - CARDIOMIOPATIA ISQUEMICA'
#  'J449 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA NO ESPECIFICADA'
#  'E104 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES NEUROLOGICAS'
#  'G301 - ENFERMEDAD DE ALZHEIMER DE COMIENZO TARDIO'
#  'E039 - HIPOTIROIDISMO NO ESPECIFICADO'
#  'E102 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES RENALES'
#  'I870 - SÃ\x8dNDROME POSTROMBOTICO'
#  'I219 - INFARTO AGUDO DEL MIOCARDIO SIN OTRA ESPECIFICACION'
#  'E108 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES NO ESPECIFICADAS'
#  'I250 - ENFERMEDAD CARDIOVASCULAR ATEROSCLEROTICA ASI DESCRITA'
#  'N189 - ENFERMEDAD RENAL CRONICA, NO ESPECIFICADA'
#  'F317 - TRASTORNO AFECTIVO BIPOLAR ACTUALMENTE EN REMISION'
#  'I771 - ESTRECHEZ ARTERIAL'
#  'I702 - ATEROSCLEROSIS DE LAS ARTERIAS DE LOS MIEMBROS'
#  'I48X - FIBRILACION Y ALETEO AURICULAR'
#  'I110 - ENFERMEDAD CARDIACA HIPERTENSIVA CON INSUFICIENCIA CARDIACA (CONGESTIVA)'
#  'F001 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER DE COMIENZO TARDIO'
#  'G309 - ENFERMEDAD DE ALZHEIMER NO ESPECIFICADA'
#  'M314 - SINDROME DEL CAYADO DE LA AORTA [TAKAYASU]'
#  'I509 - INSUFICIENCIA CARDIACA NO ESPECIFICADA'
#  'I713 - RUPTURA DE ANEURISMA DE LA AORTA ABDOMINAL'
#  'Z950 - PRESENCIA DE DISPOSITIVOS CARDIACOS ELECTRONICOS'
#  'E105 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES CIRCULATORIAS PERIFERICAS'
#  'J441 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EXACERBACION AGUDA NO ESPECIFICADA'
#  'N180 - INSUFICIENCIA RENAL TERMINAL'
#  'I500 - INSUFICIENCIA CARDIACA CONGESTIVA' 'I772 - RUPTURA ARTERIAL'
#  'R030 - LECTURA ELEVADA DE LA PRESION SANGUINEA SIN DIAGNOSTICO DE HIPERTENSION'
#  'I678 - OTRAS ENFERMEDADES CEREBROVASCULARES ESPECIFICADAS'
#  'E782 - HIPERLIPIDEMIA MIXTA'
#  'F318 - OTROS TRASTORNOS AFECTIVOS BIPOLARES'
#  'N319 - DISFUNCION NEUROMUSCULAR DE LA VEJIGA NO ESPECIFICADA'
#  'E041 - NODULO TIROIDEO SOLITARIO NO TOXICO' 'G408 - OTRAS EPILEPSIAS'
#  'I679 - ENFERMEDAD CEREBROVASCULAR NO ESPECIFICADA'
#  'O100 - HIPERTENSION ESENCIAL PREEXISTENTE QUE COMPLICA EL EMBARAZO EL PARTO Y EL PUERPERIO'
#  'J458 - ASMA MIXTA' 'R521 - DOLOR CRONICO INTRATABLE'
#  'F009 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER NO ESPECIFICADA'
#  'D508 - OTRAS ANEMIAS POR DEFICIENCIA DE HIERRO'
#  'E784 - OTRA HIPERLIPIDEMIA'
#  'D093 - CARCINOMA IN SITU DE LA GLANDULA TIROIDES Y DE OTRAS GLANDULAS ENDOCRINAS'
#  'F002 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER ATIPICA O DE TIPO MIXTO'
#  'K746 - OTRAS CIRROSIS DEL HIGADO Y LAS NO ESPECIFICADAS'
#  'K717 - ENFERMEDAD TOXICA DEL HIGADO CON CIRROSIS Y FIBROSIS DEL HIGADO'
#  'E116 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON OTRAS COMPLICACIONES ESPECIFICADAS'
#  'J440 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON INFECCION AGUDA DE LAS VIAS RESPIRATORIAS INFERIORES'
#  'E748 - OTROS TRASTORNOS ESPECIFICADOS DEL METABOLISMO DE LOS CARBOHIDRATOS'
#  'I259 - ENFERMEDAD ISQUEMICA CRONICA DEL CORAZON NO ESPECIFICADA'
#  'E112 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES RENALES'
#  'I729 - ANEURISMA Y DISECCION DE SITIO NO ESPECIFICADO'
#  'E117 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES MULTIPLES'
#  'E106 - DIABETES MELLITUS INSULINODEPENDIENTE CON OTRAS COMPLICACIONES ESPECIFICADAS'
#  'C61X - TUMOR MALIGNO DE LA PROSTATA'
#  'M810 - OSTEOPOROSIS POSTMENOPAUSICA SIN FRACTURA PATOLOGICA'
#  'E789 - TRASTORNO DEL METABOLISMO DE LAS LIPOPROTEINAS NO ESPECIFICADO'
#  'I258 - OTRAS FORMAS DE ENFERMEDAD ISQUEMICA CRONICA DEL CORAZON'
#  'I252 - INFARTO ANTIGUO DEL MIOCARDIO'
#  'G308 - OTROS TIPOS DE ENFERMEDAD DE ALZHEIMER'
#  'Z433 - ATENCION DE COLOSTOMIA' 'G20X - ENFERMEDAD DE PARKINSON'
#  'M321 - LUPUS ERITEMATOSO SISTEMICO CON COMPROMISO DE ORGANOS O SISTEMAS'
#  'G473 - APNEA DEL SUENO'
#  'I669 - OCLUSION Y ESTENOSIS DE ARTERIA CEREBRAL NO ESPECIFICADA'
#  'I058 - OTRAS ENFERMEDADES DE LA VALVULA MITRAL'
#  'M45X - ESPONDILITIS ANQUILOSANTE'
#  'E038 - OTROS HIPOTIROIDISMOS ESPECIFICADOS'
#  'M349 - ESCLEROSIS SISTEMICA NO ESPECIFICADA'
#  'N390 - INFECCION DE VIAS URINARIAS SITIO NO ESPECIFICADO'
#  'F313 - TRASTORNO AFECTIVO BIPOLAR EPISODIO DEPRESIVO PRESENTE LEVE O MODERADO'
#  'F412 - TRASTORNO MIXTO DE ANSIEDAD Y DEPRESION'
#  'I359 - TRASTORNO DE LA VALVULA AORTICA NO ESPECIFICADO'
#  'G409 - EPILEPSIA TIPO NO ESPECIFICADO' 'F208 - OTRAS ESQUIZOFRENIAS'
#  'Z921 - HISTORIA PERSONAL DE USO (PRESENTE) DE ANTICOAGULANTES POR LARGO TIEMPO'
#  'F019 - DEMENCIA VASCULAR NO ESPECIFICADA'
#  'I251 - ENFERMEDAD ATEROSCLEROTICA DEL CORAZON'
#  'M059 - ARTRITIS REUMATOIDEA SEROPOSITIVA SIN OTRA ESPECIFICACION'
#  'E113 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES OFTALMICAS'
#  'E785 - HIPERLIPIDEMIA NO ESPECIFICADA'
#  'D500 - ANEMIA POR DEFICIENCIA DE HIERRO SECUNDARIA A PERDIDA DE SANGRE (CRONICA)'
#  'F03X - DEMENCIA NO ESPECIFICADA' 'H811 - VERTIGO PAROXISTICO BENIGNO'
#  'E660 - OBESIDAD DEBIDA A EXCESO DE CALORIAS'
#  'I351 - INSUFICIENCIA (DE LA VALVULA) AORTICA'
#  'I348 - OTROS TRASTORNOS NO REUMATICOS DE LA VALVULA MITRAL'
#  'E669 - OBESIDAD NO ESPECIFICADA' 'J459 - ASMA NO ESPECIFICADO'
#  'G459 - ISQUEMIA CEREBRAL TRANSITORIA SIN OTRA ESPECIFICACION'
#  'E114 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES NEUROLOGICAS'
#  'M150 - (OSTEO)ARTROSIS PRIMARIA GENERALIZADA'
#  'M060 - ARTRITIS REUMATOIDE SERONEGATIVA'
#  'H409 - GLAUCOMA NO ESPECIFICADO'
#  'M069 - ARTRITIS REUMATOIDE NO ESPECIFICADA'
#  'F319 - TRASTORNO AFECTIVO BIPOLAR NO ESPECIFICADO'
#  'G918 - OTROS TIPOS DE HIDROCEFALO'
#  'E115 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES CIRCULATORIAS PERIFERICAS'
#  'E780 - HIPERCOLESTEROLEMIA PURA'
#  'I499 - ARRITMIA CARDIACA NO ESPECIFICADA' 'K296 - OTRAS GASTRITIS'
#  'I738 - OTRAS ENFERMEDADES VASCULARES PERIFERICAS ESPECIFICADAS'
#  'I64X - ACCIDENTE VASCULAR ENCEFALICO AGUDO NO ESPECIFICADO COMO HEMORRAGICO O ISQUEMICO'
#  'I652 - OCLUSION Y ESTENOSIS DE ARTERIA CAROTIDA'
#  'R001 - BRADICARDIA NO ESPECIFICADA'
#  'M329 - LUPUS ERITEMATOSO SISTEMICO SIN OTRA ESPECIFICACION'
#  'N184 - Enfermedad renal cronica, etapa 4'
#  'M053 - ARTRITIS REUMATOIDE CON COMPROMISO DE OTROS ORGANOS O SISTEMAS'
#  'I489 - Fibrilacion y aleteo auricular, no especificado'
#  'I698 - SECUELAS DE OTRAS ENFERMEDADES CEREBROVASCULARES ESPECIFICADAS O NO'
#  'F201 - ESQUIZOFRENIA HEBEFRENICA'
#  'Z958 - PRESENCIA DE OTROS INJERTOS Y PROTESIS CARDIOVASCULARES'
#  'L408 - OTRAS PSORIASIS' 'F059 - DELIRIO NO ESPECIFICADO'
#  'I489 - FIBRILACION Y ALETEO AURICULAR, NO ESPECIFICADO'
#  'E890 - HIPOTIROIDISMO CONSECUTIVO A PROCEDIMIENTOS'
#  'E132 - OTRAS DIABETES MELLITUS ESPECIFICADAS CON COMPLICACIONES RENALES'
#  'F209 - ESQUIZOFRENIA NO ESPECIFICADA' 'M353 - POLIMIALGIA REUMATICA'
#  'C443 - TUMOR MALIGNO DE LA PIEL DE OTRAS PARTES Y DE LAS NO ESPECIFICADAS DE LA CARA'
#  'J47X - BRONQUIECTASIA' 'I498 - OTRAS ARRITMIAS CARDIACAS ESPECIFICADAS'
#  'M340 - ESCLEROSIS SISTEMICA PROGRESIVA'
#  'I778 - OTROS TRASTORNOS ESPECIFICADOS DE ARTERIAS Y ARTERIOLAS'
#  'N185 - Enfermedad renal cronica, etapa 5'
#  'I472 - TAQUICARDIA VENTRICULAR'
#  'N183 - Enfermedad renal cronica, etapa 3' 'J451 - ASMA NO ALERGICA'
#  'J690 - NEUMONITIS DEBIDA A ASPIRACION DE ALIMENTO O VOMITO'
#  'D689 - DEFECTO DE LA COAGULACION NO ESPECIFICADO'
#  'I429 - CARDIOMIOPATIA NO ESPECIFICADA'
#  'M219 - DEFORMIDAD ADQUIRIDA DEL MIEMBRO NO ESPECIFICADA'
#  'U072 - COVID-19 VIRUS NO IDENTIFICADO'
#  'T983 - SECUELAS DE COMPLICACIONES DE LA ATENCION MEDICA Y QUIRURGICA NO CLASIFICADAS EN OTRAS PARTE'
#  'M199 - ARTROSIS NO ESPECIFICADA' 'M179 - GONARTROSIS NO ESPECIFICADA'
#  'G820 - PARAPLEJIA FLACIDA'
#  'G373 - MIELITIS TRANSVERSA AGUDA EN ENFERMEDAD DESMIELINIZANTE DEL SISTEMA NERVIOSO CENTRAL'
#  'F200 - ESQUIZOFRENIA PARANOIDE'
#  'H533 - OTROS TRASTORNOS DE LA VISION BINOCULAR'
#  'N310 - VEJIGA NEUROPATICA NO INHIBIDA NO CLASIFICADA EN OTRA PARTE'
#  'G122 - ENFERMEDADES DE LAS NEURONAS MOTORAS'
#  'S342 - TRAUMATISMO DE RAIZ NERVIOSA DE LA COLUMNA LUMBAR Y SACRA'
#  'I158 - OTROS TIPOS DE HIPERTENSION SECUNDARIA'
#  'M828 - OSTEOPOROSIS EN OTRAS ENFERMEDADES CLASIFICADAS EN OTRA PARTE'
#  'I120 - ENFERMEDAD RENAL HIPERTENSIVA CON INSUFICIENCIA RENAL'
#  'G800 - PARALISIS CEREBRAL ESPASTICA'
#  'F000 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER DE COMIENZO TEMPRANO'
#  'T913 - SECUELAS DE TRAUMATISMO DE LA MEDULA ESPINAL'
#  'F321 - EPISODIO DEPRESIVO MODERADO'
#  'F312 - TRASTORNO AFECTIVO BIPOLAR EPISODIO MANIACO PRESENTE CON SINTOMAS PSICOTICOS'
#  'G809 - PARALISIS CEREBRAL INFANTIL SIN OTRA ESPECIFICACION'
#  'T905 - SECUELAS DE TRAUMATISMO INTRACRANEAL'
#  'M800 - OSTEOPOROSIS POSTMENOPAUSICA CON FRACTURA PATOLOGICA'
#  'F018 - OTRAS DEMENCIA VASCULARES' 'N40X - HIPERPLASIA DE LA PROSTATA'
#  'G958 - OTRAS ENFERMEDADES ESPECIFICADAS DE LA MEDULA ESPINAL'
#  'E009 - SINDROME CONGENITO DE DEFICIENCIA DE YODO NO ESPECIFICADO'
#  'T908 - SECUELAS DE OTROS TRAUMATISMOS ESPECIFICADOS DE LA CABEZA'
#  'A150 - TUBERCULOSIS DEL PULMON CONFIRMADA POR HALLAZGO MICROSCOPICO DEL BACILO TUBERCULOSO EN ESPUTO CON O SIN CULTIVO'
#  'B949 - SECUELAS DE ENFERMEDADES INFECCIOSAS Y PARASITARIAS NO ESPECIFICADAS'
#  'H540 - CEGUERA BINOCULAR' 'Y835 - AMPUTACION DE MIEMBRO(S)'
#  'G403 - EPILEPSIA Y SINDROMES EPILEPTICOS IDIOPATICOS GENERALIZADOS'
#  'S341 - OTRO TRAUMATISMO DE LA MEDULA ESPINAL LUMBAR'
#  'G822 - PARAPLEJIA NO ESPECIFICADA'
#  'F023 - DEMENCIA EN LA ENFERMEDAD DE PARKINSON'
#  'I890 - LINFEDEMA NO CLASIFICADO EN OTRA PARTE'
#  'R470 - DISFASIA Y AFASIA' 'I519 - ENFERMEDAD CARDIACA NO ESPECIFICADA'
#  'T093 - TRAUMATISMO DE LA MEDULA ESPINAL NIVEL NO ESPECIFICADO'
#  'Z933 - COLOSTOMIA' 'G300 - ENFERMEDAD DE ALZHEIMER DE COMIENZO TEMPRANO'
#  'I482 - Fibrilacion auricular cronica'
#  'I059 - ENFERMEDAD VALVULAR MITRAL NO ESPECIFICADA'
#  'I480 - Fibrilacion auricular paroxistica'
#  'I516 - ENFERMEDAD CARDIOVASCULAR NO ESPECIFICADA'
#  'Z951 - PRESENCIA DE DERIVACION AORTOCORONARIA'
#  'N189 - ENFERMEDAD RENAL CRONICA NO ESPECIFICADA'
#  'G629 - POLINEUROPATIA NO ESPECIFICADA'
#  'N182 - Enfermedad renal cronica, etapa 2'
#  'N185 - ENFERMEDAD RENAL CRONICA - ETAPA 5'
#  'I489 - FIBRILACION Y ALETEO AURICULAR NO ESPECIFICADO'
#  'N19X - INSUFICIENCIA RENAL NO ESPECIFICADA'
#  'I715 - RUPTURA DE ANEURISMA DE LA AORTA TORACOABDOMINAL'
#  'D134 - TUMOR BENIGNO DEL HIGADO'
#  'N181 - Enfermedad renal cronica, etapa 1'
#  'E110 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMA'
#  'N188 - OTRAS INSUFICIENCIAS RENALES CRONICAS'
#  'I495 - SINDROME DEL SENO ENFERMO'
#  'I481 - FibrilaciÃ³n auricular persistente'
#  'F719 - RETRASO MENTAL MODERADO DETERIORO DEL COMPORTAMIENTO DE GRADO NO ESPECIFICADO'
#  'I714 - ANEURISMA DE LA AORTA ABDOMINAL SIN MENCION DE RUPTURA'
#  'I270 - HIPERTENSION PULMONAR PRIMARIA']
# ------------------------------------------------------
# Valores únicos para Analisis y conducta a seguir:
# ['ESTADIO RENAL 2 A3?RCV a 10 aÃ±os MODERADO **CLASIFICACION FUNCIONAL 2B ... indice de fragilidad BUENO apoyo monopodal FRAGIL caminata BUENO...con factores de riesgo, comorbilidades presentes paciente con antecedentes de HBP. Dermatitis. HTA, DM tipo II y dislipidemia. retinopatÃ\xada diabÃ©tica con perdida casi total en OD quien esta en metas de la presion arterial pero con glicemais ro fuera de metas, que s pueden explicar por los malos habitos alimenticios y la ingesta diaria de licor para lo que desde julio 2017 se rem
#  'Plan: - Visita domiciliaria control dentro de 2 meses - Se aÃ±ade empaglifozina - Mipres vigente de 27/08/21 para un aÃ±o - Pendiente paraclÃ\xadnicos para nefrologÃ\xada Se dan recomendaciones para evitar riesgo de caÃ\xaddas, como el uso de medios laterales en cama como barandas, cuidados de la piel para evitar lesiones por presiÃ³n como mantener hidratada y realizar cambios de posiciÃ³n cada 2 horas. Tomar medicamentos tal cual se indican en fÃ³rmula mÃ©dica. Se dan signos de alarma para consultar por urgencias, tales como dificultad para respirar, sangrado profuso, convulsiones, alteraciÃ³n del estado de conciencia y se deja nÃºmeros de mesa de ayuda en caso de dudas: 4937091. 018000521021. Se le recuerda al acompaÃ±ante que tiene derecho a aceptar o negar la realizaciÃ³n de tratamientos propuestos, ademÃ¡s de escoger si desea o no permitir la participaciÃ³n de estudiantes en la atenciÃ³n.'
#  'Plan: - Control por medicina general en un mes - ValoraciÃ³n por cardiologÃ\xada - Pendiente : ecografÃ\xada renal y de vÃ\xadas urinarias, polisomnografÃ\xada - Pendiente : ValoraciÃ³n por urologÃ\xada y dermatologÃ\xada - Terapia fÃ\xadsica x 8 - Paciente cumple con tiempo para aplicaciÃ³n de tercera vacuna para covid-19. Tiene dos dosis de astrazeneca Recomendaciones: * Se beneficia de continuar en el programa de atenciÃ³n domiciliaria por su condiciÃ³n de paciente frÃ¡gil y clase funcional IV. * Se tiene consentimiento informado diligenciado y entregado en la oficina. *Se brindan recomendaciones para prevenciÃ³n de la infecciÃ³n viral por el nuevo coronavirus: aislamiento social, lavado frecuente de manos con agua y jabÃ³n']
# ------------------------------------------------------

# %%
#Unificamos algunas categorías

# Unificar las categorías 'CC' y 'CC ' en Tipo
df_cronicos60['Tipo'] = df_cronicos60['Tipo'].replace('CC ', 'CC')

# Verificar que las categorías se hayan unificado correctamente
print(df_cronicos60['Tipo'].unique())
# Out:
# ['CC' 'CE']

# %%
# Ajustar los valores 'FrÃ¡gil' a 'Frágil' en Calificacion indice de fragilidad
df_cronicos60['Calificacion indice de fragilidad'] = df_cronicos60['Calificacion indice de fragilidad'].replace('FrÃ¡gil', 'Fragil')

# Verificar que las categorías se hayan ajustado correctamente
print(df_cronicos60['Calificacion indice de fragilidad'].unique())
# Out:
# ['Fragil' 'Normal']

# %%
# Ajustar los valores 'FrÃ¡gil' a 'Frágil' en Calificacion velocidad
df_cronicos60['Calificacion velocidad'] = df_cronicos60['Calificacion velocidad'].replace('Malo - FrÃ¡gil', 'Malo - Fragil')

# Verificar que las categorías se hayan ajustado correctamente
print(df_cronicos60['Calificacion velocidad'].unique())
# Out:
# ['Aceptable' 'Deficiente' 'Malo - Fragil' 'Bueno']

# %%
# Ajustar los valores en Diagnostico principal
df_cronicos60['Diagnostico principal'] = df_cronicos60['Diagnostico principal'].replace('I481 - FibrilaciÃ³n auricular persistente', 'I481 - FIBRILACION AURICULAR PERSISTENTE')
df_cronicos60['Diagnostico principal'] = df_cronicos60['Diagnostico principal'].replace('I870 - SÃ\x8dNDROME POSTROMBOTICO', 'I870 - SINDROME POSTROMBOTICO')
# Verificar que las categorías se hayan ajustado correctamente
print(df_cronicos60['Diagnostico principal'].unique())
# Out:
# ['I10X - HIPERTENSION ESENCIAL (PRIMARIA)'
#  'E118 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES NO ESPECIFICADAS'
#  'E109 - DIABETES MELLITUS INSULINODEPENDIENTE SIN MENCION DE COMPLICACION'
#  'E103 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES OFTALMICAS'
#  'E119 - DIABETES MELLITUS NO INSULINODEPENDIENTE SIN MENCION DE COMPLICACION'
#  'J448 - OTRAS ENFERMEDADES PULMONARES OBSTRUCTIVAS CRONICAS ESPECIFICADAS'
#  'I358 - OTROS TRASTORNOS DE LA VALVULA AORTICA'
#  'I350 - ESTENOSIS (DE LA VALVULA) AORTICA'
#  'E107 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES MULTIPLES'
#  'I694 - SECUELAS DE ENFERMEDAD CEREBROVASCULAR NO ESPECIFICADA COMO HEMORRAGICA U OCLUSIVA'
#  'I255 - CARDIOMIOPATIA ISQUEMICA'
#  'J449 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA NO ESPECIFICADA'
#  'E104 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES NEUROLOGICAS'
#  'G301 - ENFERMEDAD DE ALZHEIMER DE COMIENZO TARDIO'
#  'E039 - HIPOTIROIDISMO NO ESPECIFICADO'
#  'E102 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES RENALES'
#  'I870 - SINDROME POSTROMBOTICO'
#  'I219 - INFARTO AGUDO DEL MIOCARDIO SIN OTRA ESPECIFICACION'
#  'E108 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES NO ESPECIFICADAS'
#  'I250 - ENFERMEDAD CARDIOVASCULAR ATEROSCLEROTICA ASI DESCRITA'
#  'N189 - ENFERMEDAD RENAL CRONICA, NO ESPECIFICADA'
#  'F317 - TRASTORNO AFECTIVO BIPOLAR ACTUALMENTE EN REMISION'
#  'I771 - ESTRECHEZ ARTERIAL'
#  'I702 - ATEROSCLEROSIS DE LAS ARTERIAS DE LOS MIEMBROS'
#  'I48X - FIBRILACION Y ALETEO AURICULAR'
#  'I110 - ENFERMEDAD CARDIACA HIPERTENSIVA CON INSUFICIENCIA CARDIACA (CONGESTIVA)'
#  'F001 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER DE COMIENZO TARDIO'
#  'G309 - ENFERMEDAD DE ALZHEIMER NO ESPECIFICADA'
#  'M314 - SINDROME DEL CAYADO DE LA AORTA [TAKAYASU]'
#  'I509 - INSUFICIENCIA CARDIACA NO ESPECIFICADA'
#  'I713 - RUPTURA DE ANEURISMA DE LA AORTA ABDOMINAL'
#  'Z950 - PRESENCIA DE DISPOSITIVOS CARDIACOS ELECTRONICOS'
#  'E105 - DIABETES MELLITUS INSULINODEPENDIENTE CON COMPLICACIONES CIRCULATORIAS PERIFERICAS'
#  'J441 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EXACERBACION AGUDA NO ESPECIFICADA'
#  'N180 - INSUFICIENCIA RENAL TERMINAL'
#  'I500 - INSUFICIENCIA CARDIACA CONGESTIVA' 'I772 - RUPTURA ARTERIAL'
#  'R030 - LECTURA ELEVADA DE LA PRESION SANGUINEA SIN DIAGNOSTICO DE HIPERTENSION'
#  'I678 - OTRAS ENFERMEDADES CEREBROVASCULARES ESPECIFICADAS'
#  'E782 - HIPERLIPIDEMIA MIXTA'
#  'F318 - OTROS TRASTORNOS AFECTIVOS BIPOLARES'
#  'N319 - DISFUNCION NEUROMUSCULAR DE LA VEJIGA NO ESPECIFICADA'
#  'E041 - NODULO TIROIDEO SOLITARIO NO TOXICO' 'G408 - OTRAS EPILEPSIAS'
#  'I679 - ENFERMEDAD CEREBROVASCULAR NO ESPECIFICADA'
#  'O100 - HIPERTENSION ESENCIAL PREEXISTENTE QUE COMPLICA EL EMBARAZO EL PARTO Y EL PUERPERIO'
#  'J458 - ASMA MIXTA' 'R521 - DOLOR CRONICO INTRATABLE'
#  'F009 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER NO ESPECIFICADA'
#  'D508 - OTRAS ANEMIAS POR DEFICIENCIA DE HIERRO'
#  'E784 - OTRA HIPERLIPIDEMIA'
#  'D093 - CARCINOMA IN SITU DE LA GLANDULA TIROIDES Y DE OTRAS GLANDULAS ENDOCRINAS'
#  'F002 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER ATIPICA O DE TIPO MIXTO'
#  'K746 - OTRAS CIRROSIS DEL HIGADO Y LAS NO ESPECIFICADAS'
#  'K717 - ENFERMEDAD TOXICA DEL HIGADO CON CIRROSIS Y FIBROSIS DEL HIGADO'
#  'E116 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON OTRAS COMPLICACIONES ESPECIFICADAS'
#  'J440 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON INFECCION AGUDA DE LAS VIAS RESPIRATORIAS INFERIORES'
#  'E748 - OTROS TRASTORNOS ESPECIFICADOS DEL METABOLISMO DE LOS CARBOHIDRATOS'
#  'I259 - ENFERMEDAD ISQUEMICA CRONICA DEL CORAZON NO ESPECIFICADA'
#  'E112 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES RENALES'
#  'I729 - ANEURISMA Y DISECCION DE SITIO NO ESPECIFICADO'
#  'E117 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES MULTIPLES'
#  'E106 - DIABETES MELLITUS INSULINODEPENDIENTE CON OTRAS COMPLICACIONES ESPECIFICADAS'
#  'C61X - TUMOR MALIGNO DE LA PROSTATA'
#  'M810 - OSTEOPOROSIS POSTMENOPAUSICA SIN FRACTURA PATOLOGICA'
#  'E789 - TRASTORNO DEL METABOLISMO DE LAS LIPOPROTEINAS NO ESPECIFICADO'
#  'I258 - OTRAS FORMAS DE ENFERMEDAD ISQUEMICA CRONICA DEL CORAZON'
#  'I252 - INFARTO ANTIGUO DEL MIOCARDIO'
#  'G308 - OTROS TIPOS DE ENFERMEDAD DE ALZHEIMER'
#  'Z433 - ATENCION DE COLOSTOMIA' 'G20X - ENFERMEDAD DE PARKINSON'
#  'M321 - LUPUS ERITEMATOSO SISTEMICO CON COMPROMISO DE ORGANOS O SISTEMAS'
#  'G473 - APNEA DEL SUENO'
#  'I669 - OCLUSION Y ESTENOSIS DE ARTERIA CEREBRAL NO ESPECIFICADA'
#  'I058 - OTRAS ENFERMEDADES DE LA VALVULA MITRAL'
#  'M45X - ESPONDILITIS ANQUILOSANTE'
#  'E038 - OTROS HIPOTIROIDISMOS ESPECIFICADOS'
#  'M349 - ESCLEROSIS SISTEMICA NO ESPECIFICADA'
#  'N390 - INFECCION DE VIAS URINARIAS SITIO NO ESPECIFICADO'
#  'F313 - TRASTORNO AFECTIVO BIPOLAR EPISODIO DEPRESIVO PRESENTE LEVE O MODERADO'
#  'F412 - TRASTORNO MIXTO DE ANSIEDAD Y DEPRESION'
#  'I359 - TRASTORNO DE LA VALVULA AORTICA NO ESPECIFICADO'
#  'G409 - EPILEPSIA TIPO NO ESPECIFICADO' 'F208 - OTRAS ESQUIZOFRENIAS'
#  'Z921 - HISTORIA PERSONAL DE USO (PRESENTE) DE ANTICOAGULANTES POR LARGO TIEMPO'
#  'F019 - DEMENCIA VASCULAR NO ESPECIFICADA'
#  'I251 - ENFERMEDAD ATEROSCLEROTICA DEL CORAZON'
#  'M059 - ARTRITIS REUMATOIDEA SEROPOSITIVA SIN OTRA ESPECIFICACION'
#  'E113 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES OFTALMICAS'
#  'E785 - HIPERLIPIDEMIA NO ESPECIFICADA'
#  'D500 - ANEMIA POR DEFICIENCIA DE HIERRO SECUNDARIA A PERDIDA DE SANGRE (CRONICA)'
#  'F03X - DEMENCIA NO ESPECIFICADA' 'H811 - VERTIGO PAROXISTICO BENIGNO'
#  'E660 - OBESIDAD DEBIDA A EXCESO DE CALORIAS'
#  'I351 - INSUFICIENCIA (DE LA VALVULA) AORTICA'
#  'I348 - OTROS TRASTORNOS NO REUMATICOS DE LA VALVULA MITRAL'
#  'E669 - OBESIDAD NO ESPECIFICADA' 'J459 - ASMA NO ESPECIFICADO'
#  'G459 - ISQUEMIA CEREBRAL TRANSITORIA SIN OTRA ESPECIFICACION'
#  'E114 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES NEUROLOGICAS'
#  'M150 - (OSTEO)ARTROSIS PRIMARIA GENERALIZADA'
#  'M060 - ARTRITIS REUMATOIDE SERONEGATIVA'
#  'H409 - GLAUCOMA NO ESPECIFICADO'
#  'M069 - ARTRITIS REUMATOIDE NO ESPECIFICADA'
#  'F319 - TRASTORNO AFECTIVO BIPOLAR NO ESPECIFICADO'
#  'G918 - OTROS TIPOS DE HIDROCEFALO'
#  'E115 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMPLICACIONES CIRCULATORIAS PERIFERICAS'
#  'E780 - HIPERCOLESTEROLEMIA PURA'
#  'I499 - ARRITMIA CARDIACA NO ESPECIFICADA' 'K296 - OTRAS GASTRITIS'
#  'I738 - OTRAS ENFERMEDADES VASCULARES PERIFERICAS ESPECIFICADAS'
#  'I64X - ACCIDENTE VASCULAR ENCEFALICO AGUDO NO ESPECIFICADO COMO HEMORRAGICO O ISQUEMICO'
#  'I652 - OCLUSION Y ESTENOSIS DE ARTERIA CAROTIDA'
#  'R001 - BRADICARDIA NO ESPECIFICADA'
#  'M329 - LUPUS ERITEMATOSO SISTEMICO SIN OTRA ESPECIFICACION'
#  'N184 - Enfermedad renal cronica, etapa 4'
#  'M053 - ARTRITIS REUMATOIDE CON COMPROMISO DE OTROS ORGANOS O SISTEMAS'
#  'I489 - Fibrilacion y aleteo auricular, no especificado'
#  'I698 - SECUELAS DE OTRAS ENFERMEDADES CEREBROVASCULARES ESPECIFICADAS O NO'
#  'F201 - ESQUIZOFRENIA HEBEFRENICA'
#  'Z958 - PRESENCIA DE OTROS INJERTOS Y PROTESIS CARDIOVASCULARES'
#  'L408 - OTRAS PSORIASIS' 'F059 - DELIRIO NO ESPECIFICADO'
#  'I489 - FIBRILACION Y ALETEO AURICULAR, NO ESPECIFICADO'
#  'E890 - HIPOTIROIDISMO CONSECUTIVO A PROCEDIMIENTOS'
#  'E132 - OTRAS DIABETES MELLITUS ESPECIFICADAS CON COMPLICACIONES RENALES'
#  'F209 - ESQUIZOFRENIA NO ESPECIFICADA' 'M353 - POLIMIALGIA REUMATICA'
#  'C443 - TUMOR MALIGNO DE LA PIEL DE OTRAS PARTES Y DE LAS NO ESPECIFICADAS DE LA CARA'
#  'J47X - BRONQUIECTASIA' 'I498 - OTRAS ARRITMIAS CARDIACAS ESPECIFICADAS'
#  'M340 - ESCLEROSIS SISTEMICA PROGRESIVA'
#  'I778 - OTROS TRASTORNOS ESPECIFICADOS DE ARTERIAS Y ARTERIOLAS'
#  'N185 - Enfermedad renal cronica, etapa 5'
#  'I472 - TAQUICARDIA VENTRICULAR'
#  'N183 - Enfermedad renal cronica, etapa 3' 'J451 - ASMA NO ALERGICA'
#  'J690 - NEUMONITIS DEBIDA A ASPIRACION DE ALIMENTO O VOMITO'
#  'D689 - DEFECTO DE LA COAGULACION NO ESPECIFICADO'
#  'I429 - CARDIOMIOPATIA NO ESPECIFICADA'
#  'M219 - DEFORMIDAD ADQUIRIDA DEL MIEMBRO NO ESPECIFICADA'
#  'U072 - COVID-19 VIRUS NO IDENTIFICADO'
#  'T983 - SECUELAS DE COMPLICACIONES DE LA ATENCION MEDICA Y QUIRURGICA NO CLASIFICADAS EN OTRAS PARTE'
#  'M199 - ARTROSIS NO ESPECIFICADA' 'M179 - GONARTROSIS NO ESPECIFICADA'
#  'G820 - PARAPLEJIA FLACIDA'
#  'G373 - MIELITIS TRANSVERSA AGUDA EN ENFERMEDAD DESMIELINIZANTE DEL SISTEMA NERVIOSO CENTRAL'
#  'F200 - ESQUIZOFRENIA PARANOIDE'
#  'H533 - OTROS TRASTORNOS DE LA VISION BINOCULAR'
#  'N310 - VEJIGA NEUROPATICA NO INHIBIDA NO CLASIFICADA EN OTRA PARTE'
#  'G122 - ENFERMEDADES DE LAS NEURONAS MOTORAS'
#  'S342 - TRAUMATISMO DE RAIZ NERVIOSA DE LA COLUMNA LUMBAR Y SACRA'
#  'I158 - OTROS TIPOS DE HIPERTENSION SECUNDARIA'
#  'M828 - OSTEOPOROSIS EN OTRAS ENFERMEDADES CLASIFICADAS EN OTRA PARTE'
#  'I120 - ENFERMEDAD RENAL HIPERTENSIVA CON INSUFICIENCIA RENAL'
#  'G800 - PARALISIS CEREBRAL ESPASTICA'
#  'F000 - DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER DE COMIENZO TEMPRANO'
#  'T913 - SECUELAS DE TRAUMATISMO DE LA MEDULA ESPINAL'
#  'F321 - EPISODIO DEPRESIVO MODERADO'
#  'F312 - TRASTORNO AFECTIVO BIPOLAR EPISODIO MANIACO PRESENTE CON SINTOMAS PSICOTICOS'
#  'G809 - PARALISIS CEREBRAL INFANTIL SIN OTRA ESPECIFICACION'
#  'T905 - SECUELAS DE TRAUMATISMO INTRACRANEAL'
#  'M800 - OSTEOPOROSIS POSTMENOPAUSICA CON FRACTURA PATOLOGICA'
#  'F018 - OTRAS DEMENCIA VASCULARES' 'N40X - HIPERPLASIA DE LA PROSTATA'
#  'G958 - OTRAS ENFERMEDADES ESPECIFICADAS DE LA MEDULA ESPINAL'
#  'E009 - SINDROME CONGENITO DE DEFICIENCIA DE YODO NO ESPECIFICADO'
#  'T908 - SECUELAS DE OTROS TRAUMATISMOS ESPECIFICADOS DE LA CABEZA'
#  'A150 - TUBERCULOSIS DEL PULMON CONFIRMADA POR HALLAZGO MICROSCOPICO DEL BACILO TUBERCULOSO EN ESPUTO CON O SIN CULTIVO'
#  'B949 - SECUELAS DE ENFERMEDADES INFECCIOSAS Y PARASITARIAS NO ESPECIFICADAS'
#  'H540 - CEGUERA BINOCULAR' 'Y835 - AMPUTACION DE MIEMBRO(S)'
#  'G403 - EPILEPSIA Y SINDROMES EPILEPTICOS IDIOPATICOS GENERALIZADOS'
#  'S341 - OTRO TRAUMATISMO DE LA MEDULA ESPINAL LUMBAR'
#  'G822 - PARAPLEJIA NO ESPECIFICADA'
#  'F023 - DEMENCIA EN LA ENFERMEDAD DE PARKINSON'
#  'I890 - LINFEDEMA NO CLASIFICADO EN OTRA PARTE'
#  'R470 - DISFASIA Y AFASIA' 'I519 - ENFERMEDAD CARDIACA NO ESPECIFICADA'
#  'T093 - TRAUMATISMO DE LA MEDULA ESPINAL NIVEL NO ESPECIFICADO'
#  'Z933 - COLOSTOMIA' 'G300 - ENFERMEDAD DE ALZHEIMER DE COMIENZO TEMPRANO'
#  'I482 - Fibrilacion auricular cronica'
#  'I059 - ENFERMEDAD VALVULAR MITRAL NO ESPECIFICADA'
#  'I480 - Fibrilacion auricular paroxistica'
#  'I516 - ENFERMEDAD CARDIOVASCULAR NO ESPECIFICADA'
#  'Z951 - PRESENCIA DE DERIVACION AORTOCORONARIA'
#  'N189 - ENFERMEDAD RENAL CRONICA NO ESPECIFICADA'
#  'G629 - POLINEUROPATIA NO ESPECIFICADA'
#  'N182 - Enfermedad renal cronica, etapa 2'
#  'N185 - ENFERMEDAD RENAL CRONICA - ETAPA 5'
#  'I489 - FIBRILACION Y ALETEO AURICULAR NO ESPECIFICADO'
#  'N19X - INSUFICIENCIA RENAL NO ESPECIFICADA'
#  'I715 - RUPTURA DE ANEURISMA DE LA AORTA TORACOABDOMINAL'
#  'D134 - TUMOR BENIGNO DEL HIGADO'
#  'N181 - Enfermedad renal cronica, etapa 1'
#  'E110 - DIABETES MELLITUS NO INSULINODEPENDIENTE CON COMA'
#  'N188 - OTRAS INSUFICIENCIAS RENALES CRONICAS'
#  'I495 - SINDROME DEL SENO ENFERMO'
#  'I481 - FIBRILACION AURICULAR PERSISTENTE'
#  'F719 - RETRASO MENTAL MODERADO DETERIORO DEL COMPORTAMIENTO DE GRADO NO ESPECIFICADO'
#  'I714 - ANEURISMA DE LA AORTA ABDOMINAL SIN MENCION DE RUPTURA'
#  'I270 - HIPERTENSION PULMONAR PRIMARIA']

# %% [markdown]
# ## Exportamos bases preprocesadas

# %%
df_usuarios60.to_csv('df_usuarios60.csv', index=False)
df_egresos60.to_csv('df_egresos60.csv', index=False)
df_cronicos60.to_csv('df_cronicos60.csv', index=False)

# %%
files.download('df_usuarios60.csv')
files.download('df_egresos60.csv')
files.download('df_cronicos60.csv')

# %% [markdown]
# #Análisis exploratorio

# %% [markdown]
# ##Base usuarios

# %%
#Resumen Estadístico: Descripción básica de las variables numéricas
print(df_usuarios60.describe())
# Out:
#                 YEAR         NRODOC           EDAD
# count  130595.000000  130595.000000  130595.000000
# mean     2019.732218  309848.536812      76.842651
# std         1.818790    2138.946885       9.089157
# min      2017.000000  306221.000000      60.000000
# 25%      2018.000000  308030.000000      70.000000
# 50%      2021.000000  309818.000000      76.000000
# 75%      2021.000000  311546.000000      84.000000
# max      2022.000000  314288.000000     106.000000

# %%
# Distribución de variables numéricas
df_usuarios60.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
#Distribución de Variables Categóricas
for column in df_usuarios60.select_dtypes(include=['object']).columns:
    print(df_usuarios60[column].value_counts())
# Out:
# MES
# OCTUBRE       12485
# ENERO         12484
# DICIEMBRE     12456
# SEPTIEMBRE    12351
# FEBRERO       12347
# MARZO         12267
# JUNIO         12026
# MAYO          11979
# AGOSTO         8119
# JULIO          8112
# NOVIEMBRE      8110
# ABRIL          7859
# Name: count, dtype: int64
# SEXO
# F    83774
# M    46821
# Name: count, dtype: int64
# CICLO_VITAL
# Vejez    130595
# Name: count, dtype: int64
# QUINQUENIO
# 75-79     24956
# 70-74     23335
# 80-84     22711
# 65-69     18600
# 85-89     16554
# 60-64     12720
# >90       11719
# Name: count, dtype: int64

# %%
#Comparación entre grupos
sns.boxplot(x='SEXO', y='EDAD', data=df_usuarios60)
plt.show()

# %% [markdown]
# ##Base egresos

# %%
#Resumen Estadístico: Descripción básica de las variables numéricas
print(df_egresos60.describe())
# Out:
#               YEAR  NRO ATENCION   NRO INGRESO         NRODOC  \
# count  3737.000000  3.737000e+03  3.737000e+03    3737.000000
# mean   2019.130586  4.720614e+06  2.912322e+06  309637.522344
# min    2017.000000  3.563763e+06  2.035230e+06  306223.000000
# 25%    2018.000000  4.035078e+06  2.265138e+06  307845.000000
# 50%    2018.000000  4.384978e+06  2.432683e+06  309697.000000
# 75%    2021.000000  5.630625e+06  3.847111e+06  311371.000000
# max    2021.000000  5.935800e+06  4.167574e+06  314023.000000
# std       1.474468  7.939285e+05  8.034599e+05    2012.730756
#
#                     FECHA NACIMIENTO         FECHA INGRESO SERVICIO  \
# count                           3737                           3737
# mean   1941-04-29 11:28:35.707787008  2019-08-24 04:54:21.916619776
# min              1912-10-27 00:00:00     2017-12-19 17:40:00.860000
# 25%              1934-05-27 00:00:00  2018-06-07 00:00:58.123000064
# 50%              1940-10-25 00:00:00  2018-10-21 16:07:18.303000064
# 75%              1948-02-20 00:00:00  2021-05-07 15:43:32.209999872
# max              1962-06-02 00:00:00     2021-12-31 17:27:17.290000
# std                              NaN                            NaN
#
#                         FECHA SALIDA  DEMORA SALIDA CLINICA (DIAS)  \
# count                           3737                   3737.000000
# mean   2019-08-29 07:34:40.041744640                      0.018999
# min              2017-12-21 14:08:28                     -4.000000
# 25%              2018-06-12 19:01:54                      0.000000
# 50%              2018-10-26 18:35:29                      0.000000
# 75%              2021-05-10 21:40:25                      0.000000
# max              2021-12-31 17:57:06                      1.000000
# std                              NaN                      0.154908
#
#        TIEMPO ESTANCIA (DIAS)
# count             3737.000000
# mean                 4.566765
# min                 -4.000000
# 25%                  1.000000
# 50%                  3.000000
# 75%                  6.000000
# max                 66.000000
# std                  5.543424

# %%
# Distribución de variables numéricas
df_egresos60.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
#Distribución de Variables Categóricas
for column in df_egresos60.select_dtypes(include=['object']).columns:
    print(df_egresos60[column].value_counts())
# Out:
# MES
# DICIEMBRE     418
# MARZO         362
# OCTUBRE       353
# AGOSTO        344
# SEPTIEMBRE    337
# JUNIO         316
# JULIO         314
# ENERO         313
# FEBRERO       303
# NOVIEMBRE     296
# MAYO          295
# ABRIL          86
# Name: count, dtype: int64
# TIPO IDENTIFICACION
# CC    3737
# Name: count, dtype: int64
# REGIMEN AFILIACION
# Contributivo          3731
# Soat                     2
# Subsidiado               2
# Particular               1
# Medicina prepagada       1
# Name: count, dtype: int64
# MODALIDAD CONTRATO
# PGP       3637
# Evento     100
# Name: count, dtype: int64
# FUENTE FINANCIACION1
# NUEVA EPS                      3733
# QBE SEGUROS S.A.                  1
# PARTICULAR                        1
# AXA COLPATRIA SEGUROS S.A         1
# ALLIANZ SEGUROS DE VIDA S.A       1
# Name: count, dtype: int64
# FUENTE FINANCIACION2
# NUEVA EPS                           3424
# Sin información                      290
# PARTICULAR                            18
# UNIVERSIDAD DE ANTIOQUIA               3
# JSS Medical Research LATAM S.A.S       1
# NO IDENTIFICADO EN EL SGSSS            1
# Name: count, dtype: int64
# VIA INGRESO
# Urgencias                        2598
# Remitido                          955
# Consulta Externa ó Programada     184
# Name: count, dtype: int64
# SERVICIO EGRESO
# Piso 5 Medicina Interna Sur          541
# Piso 7 Medicina Interna Norte        464
# Piso 7 Medicina Interna Sur          437
# Piso 4 Medicina Interna Sur          196
# Piso 5 Medicina Interna Norte        186
# Piso_10 Medicina Interna             164
# Piso 9 Medicina Interna Sur          126
# Piso 8 Medicina Interna Norte        125
# Piso 8 Medicina Interna Sur          124
# Piso 2 Occidente                      98
# Piso 3 Occidente                      97
# Piso 6 Medicina Interna Norte         80
# Camillas Sala 5 Urgencias             71
# Piso 3 Oriente                        70
# Camillas Sala 6  Urgencias            68
# Camillas Sala 3  Urgencias            67
# Piso 3                                65
# Camillas Sala 7  Urgencias            62
# Piso 4 Medicina Interna Norte         48
# Camillas Sala 4  Urgencias            46
# Sala de altas                         42
# Expansión                             42
# Camillas Sala 2  Urgencias            41
# Camillas SAI Adultos                  38
# Piso 6 Medicina Interna Sur           37
# ERA 1                                 34
# Piso 6 UCE                            33
# Piso 2 Oriente                        28
# Fast track 1                          28
# Camillas Sala 1  Urgencias            27
# Fast track 2                          26
# Piso 4 Oriente                        23
# Piso 9 Medicina Interna Norte         23
# Traumas Urgencias                     18
# Camillas Sala 8 Urgencias             17
# ERA                                   15
# ERA 2                                 14
# Piso 4 UCI Occidente                  14
# Piso 7 UCI Cardiovascular             13
# Piso 4 UCI Oriente                     9
# Piso 4 UCI-V                           9
# Camillas Sala 8 - Blanca               8
# Piso 5 UCI                             8
# Piso 7 UCI Medicoquirúrgica            8
# Observación Individual                 7
# Piso 4 Occidente                       5
# Piso 2 UCI Occidente                   5
# Camillas Sala Remitidos                5
# Piso 7 UCE                             4
# UCI Urgencias                          4
# Piso 8 Proc Menores                    3
# Piso 7 UCI Neurocirugía                3
# Observación Paciente Respiratorio      3
# Reanimación COVID                      2
# Piso 2 UCE                             2
# Piso 3 UCE                             2
# Camillas Sala 8  Urgencias             1
# Urgencias Expansion 1                  1
# Name: count, dtype: int64
# TIPO EGRESO
# Alta Médica                    3250
# Fallece                         349
# Remisión a otra institución     125
# Alta Voluntaria                  13
# Name: count, dtype: int64
# FECHA INGRESO CLINICA
# 2018-02-21 05:21:03.340    1
# 2018-01-06 02:06:44.877    1
# 2018-01-06 11:56:27.203    1
# 2018-10-22 14:51:09.647    1
# 2021-06-22 23:35:53.903    1
#                           ..
# 2018-10-30 09:42:19.397    1
# 2021-09-13 14:50:31.690    1
# 2018-10-09 15:35:24.343    1
# 2021-02-03 20:54:55.703    1
# 2021-10-28 02:27:30.293    1
# Name: count, Length: 3737, dtype: int64
# TIPO DIAGNOSTICO PRINCIPAL
# Sin Informacion    1655
# Nuevo              1278
# Repetido            804
# Name: count, dtype: int64

# %%
#Correlación entre Variables: Matriz de correlación para variables numéricas.
# Seleccionar solo las columnas numéricas
numeric_cols = df_egresos60.select_dtypes(include=['float64', 'int64']).columns

# Calcular la matriz de correlación
corr_matrix = df_egresos60[numeric_cols].corr()

# Visualizar la matriz de correlación
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de correlación')
plt.show()

# %%
#Comparación entre Grupos
sns.boxplot(x='YEAR', y='TIEMPO ESTANCIA (DIAS)', data=df_egresos60)
plt.show()

# %% [markdown]
# ##Base crónicos

# %%
# Resumen Estadístico:Descripción básica de las variables numéricas
print(df_cronicos60.describe())
# Out:
#                YEAR      Atencion       Ingreso         NRODOC          Peso  \
# count  26322.000000  2.632200e+04  2.632200e+04   26322.000000  26322.000000
# mean    2019.962883  4.967856e+06  3.490407e+06  309819.212560     71.122153
# std        1.796458  8.222090e+05  6.629563e+05    2068.403296    384.777876
# min     2017.000000  3.408530e+06  2.049927e+06  306221.000000      5.000000
# 25%     2018.000000  4.228058e+06  2.808843e+06  308055.000000     59.000000
# 50%     2021.000000  5.093746e+06  3.748032e+06  309833.000000     68.000000
# 75%     2021.000000  5.789290e+06  4.076914e+06  311499.000000     77.000000
# max     2022.000000  6.125234e+06  4.365936e+06  314219.000000  62153.000000
#
#               Talla            IMC  Saturacion de oxigeno  Perimetro muslo  \
# count  26322.000000   26322.000000           26322.000000     26322.000000
# mean     157.804547     256.433114              94.326153        49.155155
# std      159.550456    8895.739924               7.320142        37.306752
# min        0.000000       0.000000               0.000000         0.000000
# 25%      150.000000      24.350000              93.000000        42.000000
# 50%      155.000000      27.390000              95.000000        50.000000
# 75%      162.000000      31.200000              96.000000        56.000000
# max    15797.000000  730000.000000             891.000000      5730.000000
#
#        Perimetro cintura  ...  Colesterol total  Trigliceridos  \
# count       26322.000000  ...      26322.000000   26322.000000
# mean           96.910831  ...        145.193826     145.556820
# std            68.784127  ...         61.154591     273.832021
# min             0.000000  ...          0.000000       0.000000
# 25%            89.000000  ...        117.325000      86.900000
# 50%            98.000000  ...        142.000000     122.000000
# 75%           107.000000  ...        172.000000     172.000000
# max         10758.000000  ...       1947.000000   15121.000000
#
#        Creatinina 1 consulta  Tasa de filtracion glomerular TFG  \
# count           26322.000000                       26322.000000
# mean                1.105269                          61.680861
# std                 2.144434                         342.543254
# min                 0.010000                           0.440000
# 25%                 0.770000                          40.855000
# 50%                 1.000000                          54.035000
# 75%                 1.060000                          72.157500
# max               112.000000                       55031.300000
#
#        Microalbuminuria  Hormona Estimulante de la Tiroides (TSH)  \
# count      26322.000000                              26322.000000
# mean          43.044668                                  4.023435
# std          314.678461                                 69.518955
# min            0.000000                                  0.000000
# 25%            0.150000                                  0.220000
# 50%            1.790000                                  1.960000
# 75%            9.777500                                  3.570000
# max        23138.000000                               5367.000000
#
#        Creatinina 2 consulta  Tasa de filtracion glomerular TFG2  \
# count           26322.000000                        26322.000000
# mean                0.642591                           34.648873
# std                 1.343547                           50.516197
# min                 0.000000                            0.000000
# 25%                 0.000000                            0.000000
# 50%                 0.680000                           34.010000
# 75%                 1.000000                           57.957500
# max               125.000000                         5503.750000
#
#        Meses de diferencia entre TFG  Cambio de TFG
# count                   26322.000000   26322.000000
# mean                        1.985905       0.123506
# std                         4.509730       3.883935
# min                         0.000000    -219.110000
# 25%                         0.000000       0.000000
# 50%                         0.000000       0.000000
# 75%                         3.000000       0.000000
# max                       192.000000     244.860000
#
# [8 rows x 39 columns]

# %%
#Distribución de Variables Numéricas
df_cronicos60.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
#Distribución de Variables Categóricas: Conteo de valores únicos para variables categóricas
for column in df_cronicos60.select_dtypes(include=['object']).columns:
    print(df_cronicos60[column].value_counts())
# Out:
# MES
# MARZO         3152
# FEBRERO       2867
# DICIEMBRE     2612
# MAYO          2543
# OCTUBRE       2452
# NOVIEMBRE     2337
# ENERO         2082
# AGOSTO        1984
# JULIO         1643
# SEPTIEMBRE    1594
# ABRIL         1557
# JUNIO         1499
# Name: count, dtype: int64
# Fecha diligenciamiento
# 27/10/2021    88
# 28/10/2021    85
# 23/03/2022    83
# 6/12/2021     81
# 14/02/2022    80
#               ..
# 17/10/2021     1
# 9/01/2022      1
# 2/01/2022      1
# 28/11/2021     1
# 29/05/2022     1
# Name: count, Length: 764, dtype: int64
# Hora
# 11:12:08 a.m.     357
# 1:19:15 p.m.        5
# 11:38:59 a.m.       5
# 10:46:31 a.m.       5
# 9:26:49 a. m.       4
#                  ...
# 12:01:18 p. m.      1
# 11:53:48 a. m.      1
# 11:19:30 a. m.      1
# 11:14:37 a. m.      1
# 11:25:39 p.m.       1
# Name: count, Length: 22441, dtype: int64
# Tipo
# CC    26311
# CE       11
# Name: count, dtype: int64
# Clasificacion IMC
# Sobrepeso         10046
# Obesidad Grasa     8369
# Normal             7400
# Bajo                507
# Name: count, dtype: int64
# Calificacion indice de fragilidad
# Normal    14856
# Fragil    11466
# Name: count, dtype: int64
# Calificacion apoyo monopodal
# Malo - Fragil    20189
# Aceptable         5474
# Bueno              659
# Name: count, dtype: int64
# Calificacion velocidad
# Malo - Fragil    8466
# Deficiente       8409
# Aceptable        6704
# Bueno            2743
# Name: count, dtype: int64
# Diabetes Mellitus
# Si    14546
# No    11776
# Name: count, dtype: int64
# Control Diabetes
# No aplica            11776
# controlada            9839
# No controlada         3726
# Falta hemoglobina      981
# Name: count, dtype: int64
# Tiene HTA
# Si    25664
# No      658
# Name: count, dtype: int64
# Tiempo con el diagnostico1
# ND        10439
# 21.0       2663
# 22.0       1897
# 11.0       1708
# 12.0       1128
#           ...
# 2021.0        1
# 30            1
# 37            1
# 2             1
# 53.0          1
# Name: count, Length: 101, dtype: int64
# Tiene EPOC
# No                       17403
# Sospecha                  5295
# Si                        3440
# EPOC no espirometrico      184
# Name: count, dtype: int64
# Enermedad coronaria en el ultimo año
# No aplica           15582
# No                   8995
# IAM                  1362
# Angina estable        325
# Angina inestable       58
# Name: count, dtype: int64
# Insuficiencia cardiaca
# No aplica                    13416
# No                            7113
# Controlada                    5536
# No controlada                  157
# Deterioro de c. funcional       60
# Signos de sobrecarga            40
# Name: count, dtype: int64
# Valvulopatia
# No    24873
# Si     1449
# Name: count, dtype: int64
# Arritmia o paciente con dispositivo
# No    23445
# Si     2877
# Name: count, dtype: int64
# Sufre de alguna enfermedad cardiovascular
# No    13550
# Si    12772
# Name: count, dtype: int64
# Tabaquismo
# No            23026
# Si             2019
# Ex-fumador     1277
# Name: count, dtype: int64
# Cuantos cigarrillos al dia
# 0.0      12760
# ND       10439
# 20.0       703
# 0          677
# 10.0       503
# 5.0        218
# 3.0        138
# 40.0       114
# 2.0         87
# 1.0         82
# 6.0         80
# 4.0         74
# 7.0         70
# 8.0         64
# 30.0        64
# 15.0        50
# 10          32
# 60.0        31
# 20          25
# 12.0        20
# 50.0        14
# 5           10
# 11.0         8
# 9.0          8
# 3            7
# 1            7
# 6            5
# 30           4
# 7            4
# 205.0        4
# 40           3
# 8            3
# 2            3
# 15           2
# 4            2
# 25.0         2
# 50           1
# 35.0         1
# 35           1
# 11           1
# 9            1
# Name: count, dtype: int64
# Estadio de la Enfermedad Renal
# Estadio 2     7538
# Estadio 3A    7014
# Estadio 3B    6056
# Estadio 1     2378
# Estadio 4     2206
# Estadio 0      775
# Estadio 5      355
# Name: count, dtype: int64
# Clase Funcional
# Clase funcional 2A    9516
# Clase funcional 4     8188
# Clase funcional 2B    7419
# Clase funcional 3     1049
# Clase funcional 1      150
# Name: count, dtype: int64
# Ulcera de pie diabetico
# No    25986
# Si      336
# Name: count, dtype: int64
# Remision
# Grupal 2    15482
# Grupal 4     7914
# Grupal 3     2232
# Grupal 1      694
# Name: count, dtype: int64
# Diagnostico principal
# I10X - HIPERTENSION ESENCIAL (PRIMARIA)                                             13246
# E109 - DIABETES MELLITUS INSULINODEPENDIENTE SIN MENCION DE COMPLICACION             1536
# J449 - ENFERMEDAD PULMONAR OBSTRUCTIVA CRONIC
Vigilar signos de alarma cardiovascular como: dolor de cabeza muy fuerte con pÃ©rdida del conocimiento o con pÃ©rdida de la fuerza en una parte del cuerpo, desviaciÃ³n o torcedura de la boca, habla con la lengua enredada. mucha sed, mucho hambre. dolor en el pecho como si le estuvieran apretando que se le pasa para el cuello o para el brazo u hombro izquierdo.*******acudir inmediatamente a urgencias.                                                                                                                                                                                                                                                                                                                                                                                                               1
# Usuario que viene para ingreso al programa de riesgo cardiovascular. Trae paraclÃ­nicos del 03/07/2018, con hipertrigliceridemia. Con cifras de glucosa dentro de metas. La presiÃ³n arterial sistÃ³lica estÃ¡ ligemente elevada. PrÃ³xima consulta en 1 mes. Me piden fÃ³rmula de Trazodona y Levetiracetam.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Solicito paraclÃ­nicos. Que pida cita en 8 dÃ­as, para que me los traiga y poder decidir el manejo.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# paciente RCV alto, clase funcional:2A requiete acompaÃ±amiento de grupo interdisciplinario #2 mets: 6.11 indice de fragilidad de groningen: 1 ( normal) actualmente con HTA controlada, con DM controlada ultima hba1c:6.27% previa: 6.9% en metas, con ERC: E3a A1 evitar aines, con envejecimiento renal, siguen mejorando la creatinina, mantener vacunaciÃ³n al dia, ya se coloco influenza formulo medicamento de control por 3 meses, control en 3 meses con examenes anuales. debe continuar usando con juicio el tratamiento, en horario establecido y sin falta. evitar consumo de licor o cigarrillo, sustancias psicoactÃ­vas realizar actividad fÃ­sica ( caminar trotar, bicicleta, nataciÃ³n ) minimo 5 veces/ semana, durante 30 minutos, dieta baja en sal, grasas, harinas, cero dulces, con consumo de frutas y verduras, estar atento signos de alarma ( cefalea, mareos, disnea, polidipsia, poliÃºria, polifÃ¡gia, claudicaciÃ³n edema miembros inferiores , etc), en caso de dolor de pecho o sudoraciÃ³n excesiva con desaliento o desmayo acudir a urgencias. cuidados de los pies, usar calzado cÃ³modo que no talle, buen corte de uÃ±as,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Plan: - Control por medicina general en un mes - ValoraciÃ³n por cardiologÃ­a - Pendiente : ecografÃ­a renal y de vÃ­as urinarias, polisomnografÃ­a - Pendiente : ValoraciÃ³n por urologÃ­a y dermatologÃ­a - Terapia fÃ­sica x 8 - Paciente cumple con tiempo para aplicaciÃ³n de tercera vacuna para covid-19. Tiene dos dosis de astrazeneca Recomendaciones: * Se beneficia de continuar en el programa de atenciÃ³n domiciliaria por su condiciÃ³n de paciente frÃ¡gil y clase funcional IV. * Se tiene consentimiento informado diligenciado y entregado en la oficina. *Se brindan recomendaciones para prevenciÃ³n de la infecciÃ³n viral por el nuevo coronavirus: aislamiento social, lavado frecuente de manos con agua y jabÃ³n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Name: count, Length: 20232, dtype: int64

# %%
#Correlación entre Variables: Matriz de correlación para variables numéricas.
# Seleccionar solo las columnas numéricas
numeric_cols = df_cronicos60.select_dtypes(include=['float64', 'int64']).columns

# Calcular la matriz de correlación
corr_matrix = df_cronicos60[numeric_cols].corr()

# Visualizar la matriz de correlación
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de correlación')
plt.show()

# %%
#Comparación entre Grupos
sns.boxplot(x='Peso', y='Colesterol total', data=df_cronicos60)
plt.show()
